# %% [markdown]
# # Assignment 2
# For this assignment you'll be looking at some of my physical activity data, which I've put in `datasets/strava.csv`. The first submission due date for this assignment is **November 12th at 11:59PM**.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
df =

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1 (25%)
# This data is a bit of a mess. It includes running and cycling! Your first job is to identify the different run *sessions* from the dataset and list their *start* and *end* times. You know a given activity is a run if it has a value for `Power` (since I often use a stryd footpod) or if it came before Sept 15th (since that's when I bought a bike). And you can assume that a session is made up of contiguous values at at least a 20 minute resolution. That is, if I am running then stop recording data for 20 minutes or more then start running again that's two sessions. But if I only stop for 7 minutes, then start up again, that's just one session.
#
# Create a `DataFrame` which is made up of three columns, the `start` and `end` times of each run as described above, with a `length` field and the with the session number, starting with `0` of course, as the index.
#
# **Note**: You can find pandas frequency strings for the resampling here: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html

# %%
# read in dataframe
# set index to timsestamp
# get index < 2019-09-15
# power.notnull()
# sort index

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('strava.csv')
data = data.set_index(pd.to_datetime(data["timestamp"]))
cleaning_data = data[(data.index < ['2019-09-15']) | (data['Power'].notna())].sort_index()
cleaning_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d1c188c27134> in <module>
#       4 data = pd.read_csv('strava.csv')
#       5 data = data.set_index(pd.to_datetime(data["timestamp"]))
# ----> 6 cleaning_data = data[(data.index < ['2019-09-15']) | (data['Power'].notna())].sort_index()
#       7 cleaning_data
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/datetimelike.py in wrapper(self, other)
#     130                 other = other._values
#     131
# --> 132             result = op(self._data, maybe_unwrap_index(other))
#     133             return result
#     134
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in wrapper(self, other)
#     180             return ops.invalid_comparison(self, other, op)
#     181         elif len(other) != len(self):
# --> 182             raise ValueError("Lengths must match")
#     183         else:
#     184             if isinstance(other, list):
#
# ValueError: Lengths must match

# %%
sessions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-727cfd9ab36a> in <module>
# ----> 1 sessions
#
# NameError: name 'sessions' is not defined

# %%
#went to office hour
#working
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read csv
df = pd.read_csv('strava.csv')
#get time stamp column
df = df.set_index(pd.to_datetime(df["timestamp"]))

#get date before sept 15 (this is when he bought a bike) | ignore any nan values in the power column
df = df[(df.index < '2019-09-15') | (df['Power'].notnull())]#.sort_index()


# he wants 0 index WHY???
session_number = -1 

#this is some old date to clean up some data
last_seen = pd.to_datetime('2019-07-08')
#last_seen = 
#creates index for us
for index, row in df.iterrows(): 
    if (index - last_seen) > pd.Timedelta('20T'): #creates a time index with 20 min
        session_number = session_number + 1
    last_seen = index
    df.at[index,'sessions'] = session_number #specifying location 
    #print(index)
df = df.dropna(subset = ['sessions'])
df['sessions'] = df['sessions'].astype(int)

sessions = (df.groupby('sessions')
            .apply(lambda x: pd.Series({'start': min(x.index),'end':max(x.index),'length':pd.Interval(min(x.index),max(x.index))})))
sessions
# Out:
#                        start                 end  \
# sessions
# 0        2019-07-08 21:04:03 2019-07-08 21:23:55
# 1        2019-07-10 23:18:00 2019-07-10 23:37:20
# 2        2019-07-12 21:27:11 2019-07-12 22:30:17
# 3        2019-07-14 17:20:28 2019-07-14 18:38:22
# 4        2019-07-14 20:45:07 2019-07-14 21:04:51
# 5        2019-07-16 21:10:40 2019-07-16 21:29:10
# 10        (2019-07-21 21:58:25, 2019-07-21 22:16:30]
# 11        (2019-07-22 21:47:17, 2019-07-22 22:05:46]
# 12        (2019-07-23 00:49:07, 2019-07-23 01:14:46]
# 13        (2019-07-24 23:08:43, 2019-07-25 00:13:11]
# 14        (2019-07-26 20:10:04, 2019-07-26 21:35:38]
# 15        (2019-07-27 19:11:30, 2019-07-27 19:40:02]
# 16        (2019-07-28 18:48:46, 2019-07-28 19:21:18]
# 17        (2019-07-29 11:47:21, 2019-07-29 12:23:19]
# 18        (2019-07-30 19:31:47, 2019-07-30 20:15:27]
# 19        (2019-07-31 21:50:17, 2019-07-31 23:22:24]
# 20        (2019-08-01 21:12:10, 2019-08-01 21:28:39]
# 21        (2019-08-02 20:20:38, 2019-08-02 20:28:06]
# 22        (2019-08-03 21:49:36, 2019-08-03 22:06:40]
# 23        (2019-08-04 20:03:36, 2019-08-04 20:53:13]
# 24        (2019-08-04 21:14:39, 2019-08-04 21:26:19]
# 25        (2019-08-05 21:45:11, 2019-08-05 22:03:00]
# 26        (2019-08-06 21:49:40, 2019-08-06 22:08:09]
# 27        (2019-08-07 23:19:26, 2019-08-08 00:35:42]
# 28        (2019-08-09 21:28:40, 2019-08-09 21:47:42]
# 29        (2019-08-10 00:47:09, 2019-08-10 01:21:07]
# 30        (2019-08-11 19:46:44, 2019-08-11 20:18:23]
# 31        (2019-08-12 21:22:53, 2019-08-12 21:34:41]
# 32        (2019-08-14 23:19:16, 2019-08-14 23:54:32]
# 33        (2019-08-17 11:50:36, 2019-08-17 12:21:04]
# 34        (2019-08-18 20:41:37, 2019-08-18 20:58:33]
# 35        (2019-08-20 19:18:27, 2019-08-20 19:53:16]
# 36        (2019-08-20 20:32:57, 2019-08-20 21:13:18]
# 37        (2019-08-21 01:15:54, 2019-08-21 01:49:07]
# 38        (2019-08-21 03:24:16, 2019-08-21 03:58:43]
# 39        (2019-08-23 01:24:39, 2019-08-23 02:07:00]
# 40        (2019-08-24 19:36:17, 2019-08-24 19:57:56]
# 41        (2019-08-28 21:41:28, 2019-08-28 21:54:53]
# 42        (2019-08-31 18:45:43, 2019-08-31 19:15:29]
# 43        (2019-09-12 00:09:40, 2019-09-12 00:45:32]
# 44        (2019-09-14 20:08:40, 2019-09-14 21:37:39]

# %%
cleaning_data.datetime
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4fe6bce6a7d1> in <module>
# ----> 1 cleaning_data.datetime
#
# NameError: name 'cleaning_data' is not defined

# %%
'''
Create a DataFrame which is made up of three columns, 
the start and end times of each run as described above, 
with a length field and the with the session number, 
starting with 0 of course, as the index.
'''

cleaning_columns = data[['timestamp','Power']].notna()
#cleaning_columns = data.loc[(data['Power'] !=0 )].head()

cleaning_columns

# %%
df = pd.read_csv('strava.csv')
df = df.set_index(pd.to_datetime(df["timestamp"]))
df = df[(df.index < '2019-09-15') | (df['Power'].notnull())].sort_index()
session_number = -1 # he wants 0 index WHY
last_seen = pd.to_datetime('2012-01-01')
for index, row in df.iterrows(): #creates index for us
    if (index - last_seen) > pd.Timedelta('20T'): #creates a time index with 20 min
# %%
df
# Out:
#                      Air Power  Cadence  Form Power  Ground Time  \
# timestamp
# 2019-07-08 21:04:03        NaN      NaN         NaN          NaN
# 2019-07-08 21:04:04        NaN      NaN         NaN          NaN
# 2019-07-08 21:04:07        NaN      NaN         NaN          NaN
# 2019-07-08 21:04:14        NaN      NaN         NaN          NaN
# 2019-07-08 21:04:15        NaN      NaN         NaN          NaN
# ...                        ...      ...         ...          ...
# 2019-09-14 21:36:56        NaN      NaN         NaN          NaN
# 2019-09-14 21:37:02        NaN      NaN         NaN          NaN
# 2019-09-14 21:37:11        NaN      NaN         NaN          NaN
# 2019-09-14 21:37:16        NaN      NaN         NaN          NaN
# 2019-09-14 21:37:39        NaN      NaN         NaN          NaN
#
#                      Leg Spring Stiffness  Power  Vertical Oscillation  \
# timestamp
# 2019-07-08 21:04:03                   NaN    NaN                   NaN
# 2019-07-08 21:04:04                   NaN    NaN                   NaN
# 2019-07-08 21:04:07                   NaN    NaN                   NaN
# 2019-07-08 21:04:14                   NaN    NaN                   NaN
# 2019-07-08 21:04:15                   NaN    NaN                   NaN
# ...                                   ...    ...                   ...
# 2019-09-14 21:36:56                   NaN    NaN                   NaN
# 2019-09-14 21:37:02                   NaN    NaN                   NaN
# 2019-09-14 21:37:11                   NaN    NaN                   NaN
# 2019-09-14 21:37:16                   NaN    NaN                   NaN
# 2019-09-14 21:37:39                   NaN    NaN                   NaN
#
#                      altitude  cadence                      datafile  ...  \
# timestamp                                                             ...
# 2019-07-08 21:04:03       NaN      0.0  activities/2675855419.fit.gz  ...
# 2019-07-08 21:04:04       NaN      0.0  activities/2675855419.fit.gz  ...
# 2019-07-08 21:04:07       NaN     54.0  activities/2675855419.fit.gz  ...
# 2019-07-08 21:04:14    3747.0     77.0  activities/2675855419.fit.gz  ...
# 2019-07-08 21:04:15    3798.0     77.0  activities/2675855419.fit.gz  ...
# ...                       ...      ...                           ...  ...
# 2019-09-14 21:36:56       NaN     64.0  activities/2871922778.fit.gz  ...
# 2019-09-14 21:37:02       NaN      0.0  activities/2871922778.fit.gz  ...
# 2019-09-14 21:37:11       NaN      0.0  activities/2871922778.fit.gz  ...
# 2019-09-14 21:37:16       NaN      0.0  activities/2871922778.fit.gz  ...
# 2019-09-14 21:37:39       NaN      0.0  activities/2871922778.fit.gz  ...
#
#                      fractional_cadence  heart_rate  position_lat  \
# timestamp
# 2019-07-08 21:04:03                 0.0        68.0           NaN
# 2019-07-08 21:04:04                 0.0        68.0           NaN
# 2019-07-08 21:04:07                 0.0        71.0           NaN
# 2019-07-08 21:04:14                 0.0        77.0   504432050.0
# 2019-07-08 21:04:15                 0.0        80.0   504432492.0
# ...                                 ...         ...           ...
# 2019-09-14 21:36:56                 0.0       113.0   504552676.0
# 2019-09-14 21:37:02                 0.0       114.0   504552108.0
# 2019-09-14 21:37:11                 0.0       117.0   504552108.0
# 2019-09-14 21:37:16                 0.0       113.0   504552108.0
# 2019-09-14 21:37:39                 0.0       112.0   504552108.0
#
#                      position_long   speed            timestamp  unknown_87  \
# timestamp
# 2019-07-08 21:04:03            NaN     0.0  2019-07-08 21:04:03         0.0
# 2019-07-08 21:04:04            NaN     0.0  2019-07-08 21:04:04         0.0
# 2019-07-08 21:04:07            NaN  1316.0  2019-07-08 21:04:07         0.0
# 2019-07-08 21:04:14   -999063637.0  1866.0  2019-07-08 21:04:14         0.0
# 2019-07-08 21:04:15   -999064534.0  1894.0  2019-07-08 21:04:15         0.0
# ...                            ...     ...                  ...         ...
# 2019-09-14 21:36:56   -999308963.0     NaN  2019-09-14 21:36:56         0.0
# 2019-09-14 21:37:02   -999308706.0     NaN  2019-09-14 21:37:02         0.0
# 2019-09-14 21:37:11   -999308706.0     NaN  2019-09-14 21:37:11         0.0
# 2019-09-14 21:37:16   -999308706.0     NaN  2019-09-14 21:37:16         0.0
# 2019-09-14 21:37:39   -999308706.0     NaN  2019-09-14 21:37:39         0.0
#
#                      unknown_88 unknown_90  sessions
# timestamp
# 2019-07-08 21:04:03       300.0        NaN         1
# 2019-07-08 21:04:04       300.0        NaN         1
# 2019-07-08 21:04:07       300.0        NaN         1
# 2019-07-08 21:04:14       100.0        NaN         1
# 2019-07-08 21:04:15       100.0        NaN         1
# ...                         ...        ...       ...
# 2019-09-14 21:36:56       300.0        NaN        45
# 2019-09-14 21:37:02       300.0        NaN        45
# 2019-09-14 21:37:11       300.0        NaN        45
# 2019-09-14 21:37:16       300.0        NaN        45
# 2019-09-14 21:37:39       300.0        NaN        45
#
# [34391 rows x 23 columns]

# %%
df = pd.read_csv('strava.csv')
#df = df.set_index(pd.to_datetime(df["timestamp"]))
df = df.set_index(pd.to_datetime(df['timestamp']))
#df.head()
session_number = -1
#previous_time = 0
previous_time = pd.to_datetime('2012')

for index,row_value in df.iterrows():
    difference = index - previous_time #ValueError: Cannot add integral value to Timestamp without freq. - previous time = 0 =/= time
    if difference > pd.Timedelta('20T'):
        session_number = session_number + 1
        previous_time = index
print(session_number)

# %% [markdown]
# ## Question 2 (10%)
# How many minutes long was my longest run?

# %%
sessions['length'].max().length.seconds/60
# Out:
# 88.98333333333333

# %% [markdown]
# ## Question 3 (25%)
# It's common to estimate the calorie burn when your heart rate is between 90 and 150 beats per minute. The the equation below is suitable for men:
#
# $$((-55.0969 + (0.6309*H) + (0.1988*W) + (0.2017*A)) \div 4.184) * 60 * T$$
#
# Where HR is your heart rate in beats per minute, W is your weight in kilograms (let's be generous and assume I'm roughly 240lbs), A is the age in years (so let's go 41 here), and T is the exercise duration in hours.
#
# What I would like is for you to calculate my rolling average 5 minute caloric burn for the session which began at time `2019-08-17 11:50:36`, and report to me the time I had just finished 1 minute of my top caloric burn.

# %%
#caloric_burn_df = [(df.index >= '2019-08-17 11:50:36')]

def get_caloric_burn (heart_rate):
    caloric_burn = (-55.0969+(0.6309*np.mean(heart_rate)+(0.1988*240/2.2)+(0.2017*41))/4.184)*5
    return caloric_burn

session = df.loc[pd.to_datetime('2019-08-17 11:50:36')]['sessions']
df[df['sessions']== 33] 
df.resample('1T').fillna(method = 'ffill')
#loc is on index

df['caloric_burn'] = df['heart_rate'].rolling(60).apply(get_caloric_burn, raw=False)
df[df['caloric_burn'] == df['caloric_burn'].max()]#.index
# Out:
#                      Air Power  Cadence  Form Power  Ground Time  \
# timestamp
# 2019-08-17 12:21:04        0.0     51.0       122.0        616.0
#
#                      Leg Spring Stiffness  Power  Vertical Oscillation  \
# timestamp
# 2019-08-17 12:21:04                   0.0  217.0                   0.0
#
#                      altitude  cadence                      datafile  ...  \
# timestamp                                                             ...
# 2019-08-17 12:21:04       NaN     52.0  activities/2786247269.fit.gz  ...
#
#                      heart_rate  position_lat  position_long  speed  \
# timestamp
# 2019-08-17 12:21:04       180.0   504668892.0  -1.005696e+09    NaN
#
#                                timestamp  unknown_87  unknown_88  unknown_90  \
# timestamp
# 2019-08-17 12:21:04  2019-08-17 12:21:04         0.0       300.0        -1.0
#
#                     sessions  caloric_burn
# timestamp
# 2019-08-17 12:21:04       34   -106.174214
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Question 4 (40%)
# Today, November 1st 2019, I went out for a bike ride and wiped out. Not a little loss of control or a little skid, we're talking flying off the bike in traffic kind of wipe out. I finished my ride as I had planned, and when I was telling my wife about the incident she asked me where but I couldn't really remember. I did remember a few things though - can you help me track down where I wiped out from my ride log data, which I put in `datasets/wipout.csv`?
#
# Specifically I remember that:
# 1. I launched off the bike. So at some point both my reported speed `enhanced_speed` and my reported  `cadence` from my wearables would have been 0.
# 2. I was at least 5 minutes into my ride at the time, headed out of the city, and that it wasn't in the last ten minutes of my ride.
# 3. I know my `heart_rate` didn't drop right away. Heart rate responds relatively slowely so while my speed and cadence dropped nearly right away to zero (since my bike was lying in the road) my heart rate was still high. More specifically, I would say that compared to the 2 minutes before and 2 minutes after the event, my `heart_rate` was more than one standard deviation higher while I was lying on the grass.
# 4. I don't know if this helps, but I do remember stopping during my ride *before* I wiped out to give an in promptu lecture to a motorist on whether cars belonged in the bike lane. So some of the above criteria might also relate to that event. But I know I actually wiped out after talking to that driver.
#
# Where and when did I wipe out? In units of `timestamp` and `position_lat_degrees` and `position_long_degrees` please, so I can look this up on Google Maps.
#
# **Hint**: it might be useful to consider the heart rate carefully. Remember z-scored from STATS 250? No worries if you don't, a z-score can be created with the `scipy.stats.zscore` function. You just pass in a list of values and it returns to you a list of z-scores. This mapping is the number of standard deviations from the mean each data point is. So if a given data point has a z-score of 1.2, it is 1.2 standard deviations greater than the mean of whatever data you passed in. And z-scores can be negative too, so a z-score of -3.2 for a given data point means that data point is much smaller -- more than three standard deviations smaller -- than the mean of the rest of the data you calculated z-scores for.

# %%
wipout = pd.read_csv('wipeout.csv')
#remove 5 minutes
wipout['timestamp'] = pd.to_datetime(wipout['timestamp'])
wipout.index = wipout["timestamp"]
# wipout = wipout[["heart_rate","cadence" ,"enhanced_speed" ]]
def zscore(x):
    r = x.rolling("2t")
    m = r.mean()
    s = r.std(ddof=0)
    z = (x-m)/s
    return z
wipout["zscore_down"] = zscore(wipout["heart_rate"] )
wipout = wipout.resample("1s").interpolate(method="time")
wipout["zscore_up"]= wipout.loc[(wipout.index +pd.Timedelta(seconds=120))]["zscore_down"].reindex()
wipout['zscore_up']
#remove the first 5 minutes and last 10 minutes
start = wipout.index[0]  +pd.Timedelta(seconds=300)
end = wipout.index[-1] - pd.Timedelta(seconds=600)
#remove the first 5 minutes and last 10 minutes
wipout = wipout[(wipout["timestamp"] < end) & (wipout["timestamp"] >start) ] #question 2
#enhanced_speed and my reported cadence from my wearables would have been 0.
time_filtered = wipout[(wipout["enhanced_speed"] == 0.0)  & (wipout["cadence"] == 0.0)] #
final_val = time_filtered[(time_filtered["zscore_down"] > 1) & (time_filtered["zscore_up"]> 1)]
# Out:
# /Users/eldon/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
wipout['zscore_down']
# Out:
# timestamp
# 2019-11-01 20:17:08    1.475223
# 2019-11-01 20:17:14    1.740544
# 2019-11-01 20:17:19    1.926784
# 2019-11-01 20:17:20    1.907128
# 2019-11-01 20:17:24    2.057574
#                          ...
# 2019-11-01 21:14:53    2.295276
# 2019-11-01 21:14:55    2.935399
# 2019-11-01 21:14:59    3.335908
# 2019-11-01 21:15:01    3.178117
# 2019-11-01 21:15:04    3.209506
# Name: zscore_down, Length: 767, dtype: float64

# %%
import pandas as pd
import matplotlib as plt
import numpy as np
from scipy import stats
data=pd.read_csv('wipeout.csv')
data.head()

# %%
data=pd.read_csv('wipeout.csv')
data.head()
# Out:
#              timestamp  cadence  distance  enhanced_altitude  enhanced_speed  \
# 0  2019-11-01 20:12:03      NaN      0.00              281.6           0.000
# 1  2019-11-01 20:12:04      NaN      0.00              281.6           0.000
# 2  2019-11-01 20:12:07      NaN      0.00              281.6           0.000
# 3  2019-11-01 20:12:08      NaN      0.32              281.6           1.036
# 4  2019-11-01 20:12:10      NaN      3.30              281.8           2.976
#
#    fractional_cadence  heart_rate  position_lat  position_long  speed  \
# 0                 NaN        84.0   504424439.0   -999065791.0    NaN
# 1                 NaN        84.0   504424439.0   -999065791.0    NaN
# 2                 NaN        87.0   504424439.0   -999065791.0    NaN
# 3                 NaN        88.0   504424447.0   -999065835.0    NaN
# 4                 NaN        89.0   504424476.0   -999066382.0    NaN
#
#            timestamp.1  position_lat_degrees  position_long_degrees
# 0  2019-11-01 20:12:03             42.280368             -83.740727
# 1  2019-11-01 20:12:04             42.280368             -83.740727
# 2  2019-11-01 20:12:07             42.280368             -83.740727
# 3  2019-11-01 20:12:08             42.280369             -83.740731
# 4  2019-11-01 20:12:10             42.280371             -83.740777

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])
data = data.set_index(pd.to_datetime(data["timestamp"]))

# %%
data
# Out:
#                               timestamp  cadence  distance  enhanced_altitude  \
# timestamp
# 2019-11-01 20:12:03 2019-11-01 20:12:03      NaN      0.00              281.6
# 2019-11-01 20:12:04 2019-11-01 20:12:04      NaN      0.00              281.6
# 2019-11-01 20:12:07 2019-11-01 20:12:07      NaN      0.00              281.6
# 2019-11-01 20:12:08 2019-11-01 20:12:08      NaN      0.32              281.6
