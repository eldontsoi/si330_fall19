# %% [markdown]
# # Exercise 3
# Given this toy dataset on the size of a rectangle over time, calculate the 10 minute rolling average of the __area__ of the rectangle. If there is less than ten minutes worth of data just use all of the data which is available to you.

# %%
import pandas as pd
import numpy as np
from datetime import datetime

date_ranges=pd.date_range(start='11/4/2019', end='11/05/2019', freq='Min')

df = pd.DataFrame({"length":np.random.randint(0,50,size=(len(date_ranges))),
                   "width":np.random.randint(0,50,size=(len(date_ranges)))}, index=date_ranges)
df.head()
# Out:
#                      length  width
# 2019-11-04 00:00:00      14     44
# 2019-11-04 00:01:00      37     19
# 2019-11-04 00:02:00      23      3
# 2019-11-04 00:03:00       7      7
# 2019-11-04 00:04:00      27     41

# %%
df['area'] = df['length'] * df['width']

# %%
df['area'].resample("1T").fillna(method="ffill").rolling(10,min_periods = 1).apply(np.nanmean).plot()

# %%
df['area'].rolling(10,min_periods = 1).apply(np.nanmean).plot()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   """Entry point for launching an IPython kernel.

# %%
df['area'].resample("1S").asfreq().rolling(10*60).apply(np.mean).plot()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   """Entry point for launching an IPython kernel.

# %%
#window by default is getting the previous x minutes
#!!! predictive modeling *心心眼* :)
