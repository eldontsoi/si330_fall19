# %% [markdown]
# # Real Data Cleaning
# * I need to learn about US presidents! Let's hit wikipedia...

# %%
import pandas as pd
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_presidents_of_the_United_States")[1]
df
# Out:
#    Unaffiliated (2) Federalist (1) Democratic-Republican (4) Democratic (15) Whig (4) Republican (19) National Union (2)  \
#                                                                                                            Presidency[a]
# 0                                                   1
# 1                                                   1
# 2                                                   2
# 3                                                   3
# 4                                                   3
# ..                                                ...
# 75                                                 43
# 76                                                 43
# 77                                                 44
# 78                                                 44
# 79                                                 45
#
#                                                  \
#                       Presidency[a].1 President
# 0     April 30, 1789[d]–March 4, 1797       NaN
# 1     April 30, 1789[d]–March 4, 1797       NaN
# 2         March 4, 1797–March 4, 1801       NaN
# 3         March 4, 1801–March 4, 1809       NaN
# 4         March 4, 1801–March 4, 1809       NaN
# ..                                ...       ...
# 75  January 20, 2001–January 20, 2009       NaN
# 76  January 20, 2001–January 20, 2009       NaN
# 77  January 20, 2009–January 20, 2017       NaN
# 78  January 20, 2009–January 20, 2017       NaN
# 79         January 20, 2017–Incumbent       NaN
#
#                                                        \
#                                           President.1
# 0   George Washington1732–1799(Lived: 67 years)[3]...
# 1   George Washington1732–1799(Lived: 67 years)[3]...
# 2       John Adams1735–1826(Lived: 90 years)[6][7][8]
# 3   Thomas Jefferson1743–1826(Lived: 83 years)[9][...
# 4   Thomas Jefferson1743–1826(Lived: 83 years)[9][...
# ..                                                ...
# 75    George W. BushBorn 1946(73 years old)[126][127]
# 76    George W. BushBorn 1946(73 years old)[126][127]
# 77      Barack ObamaBorn 1961(58 years old)[128][129]
# 78      Barack ObamaBorn 1961(58 years old)[128][129]
# 79      Donald TrumpBorn 1946(73 years old)[130][131]
#
#                                                                 \
#                                       Prior office[b] Party[c]
# 0   Commander-in-Chiefof theContinental Army(1775–...      NaN
# 1   Commander-in-Chiefof theContinental Army(1775–...      NaN
# 2   1stvice president of the United States(1789–1797)      NaN
# 3   2ndvice president of the United States(1797–1801)      NaN
# 4   2ndvice president of the United States(1797–1801)      NaN
# ..                                                ...      ...
# 75                   46thgovernor of Texas(1995–2000)      NaN
# 76                   46thgovernor of Texas(1995–2000)      NaN
# 77              U.S. senator from Illinois(2005–2008)      NaN
# 78              U.S. senator from Illinois(2005–2008)      NaN
# 79  Chairman ofthe Trump Organization(1971–2017)(N...      NaN
#
#                                     \
#                Party[c].1 Election
# 0         Unaffiliated[2]  1788–89
# 1         Unaffiliated[2]     1792
# 2              Federalist     1796
# 3   Democratic-Republican     1800
# 4   Democratic-Republican     1804
# ..                    ...      ...
# 75             Republican     2000
# 76             Republican     2004
# 77             Democratic     2008
# 78             Democratic     2012
# 79             Republican     2016
#
#
#                                  Vice President
# 0                              John Adams[e][f]
# 1                              John Adams[e][f]
# 2                           Thomas Jefferson[g]
# 3       Aaron BurrMarch 4, 1801 – March 4, 1805
# 4   George ClintonMarch 4, 1805 – March 4, 1809
# ..                                          ...
# 75                                  Dick Cheney
# 76                                  Dick Cheney
# 77                                    Joe Biden
# 78                                    Joe Biden
# 79                                   Mike Pence
#
# [80 rows x 9 columns]

# %% [markdown]
# * Let's try and build a dataframe that has the president number, start and end date of term, name and birth/death years. I think there are likely questions like this on the citizenship test.

# %%
df.columns=df.columns.droplevel(0)

# %%
df.head()
# Out:
#    Presidency[a]                  Presidency[a].1  President  \
# 0              1  April 30, 1789[d]–March 4, 1797        NaN
# 1              1  April 30, 1789[d]–March 4, 1797        NaN
# 2              2      March 4, 1797–March 4, 1801        NaN
# 3              3      March 4, 1801–March 4, 1809        NaN
# 4              3      March 4, 1801–March 4, 1809        NaN
#
#                                          President.1  \
# 0  George Washington1732–1799(Lived: 67 years)[3]...
# 1  George Washington1732–1799(Lived: 67 years)[3]...
# 2      John Adams1735–1826(Lived: 90 years)[6][7][8]
# 3  Thomas Jefferson1743–1826(Lived: 83 years)[9][...
# 4  Thomas Jefferson1743–1826(Lived: 83 years)[9][...
#
#                                      Prior office[b]  Party[c]  \
# 0  Commander-in-Chiefof theContinental Army(1775–...       NaN
# 1  Commander-in-Chiefof theContinental Army(1775–...       NaN
# 2  1stvice president of the United States(1789–1797)       NaN
# 3  2ndvice president of the United States(1797–1801)       NaN
# 4  2ndvice president of the United States(1797–1801)       NaN
#
#               Party[c].1 Election                               Vice President
# 0        Unaffiliated[2]  1788–89                             John Adams[e][f]
# 1        Unaffiliated[2]     1792                             John Adams[e][f]
# 2             Federalist     1796                          Thomas Jefferson[g]
# 3  Democratic-Republican     1800      Aaron BurrMarch 4, 1801 – March 4, 1805
# 4  Democratic-Republican     1804  George ClintonMarch 4, 1805 – March 4, 1809

# %%
#val="April 30, 1789[d]–March 4, 1797"

def get_start(val):
    start=val.split("–")[0]
    return start

#get_start(val)
df["pres_start"]=df["Presidency[a].1"].apply(get_start)

# %%
def get_start_by_row0(row):
    return row["Presidency[a].1"].split("–")[0]
df.apply(get_start_by_row0, axis=1)
# Out:
# 0     April 30, 1789[d]
# 1     April 30, 1789[d]
# 2         March 4, 1797
# 3         March 4, 1801
# 4         March 4, 1801
#             ...
# 75     January 20, 2001
# 76     January 20, 2001
# 77     January 20, 2009
# 78     January 20, 2009
# 79     January 20, 2017
# Length: 80, dtype: object

# %%
def get_start_by_row(row):
    row["presy_start"]=row["Presidency[a].1"].split("–")[0]
    return row
new_df=df.apply(get_start_by_row, axis=1)
new_df
# Out:
#     Presidency[a]                    Presidency[a].1  President  \
# 0               1    April 30, 1789[d]–March 4, 1797        NaN
# 1               1    April 30, 1789[d]–March 4, 1797        NaN
# 2               2        March 4, 1797–March 4, 1801        NaN
# 3               3        March 4, 1801–March 4, 1809        NaN
# 4               3        March 4, 1801–March 4, 1809        NaN
# ..            ...                                ...        ...
# 75             43  January 20, 2001–January 20, 2009        NaN
# 76             43  January 20, 2001–January 20, 2009        NaN
# 77             44  January 20, 2009–January 20, 2017        NaN
# 78             44  January 20, 2009–January 20, 2017        NaN
# 79             45         January 20, 2017–Incumbent        NaN
#
#                                           President.1  \
# 0   George Washington1732–1799(Lived: 67 years)[3]...
# 1   George Washington1732–1799(Lived: 67 years)[3]...
# 2       John Adams1735–1826(Lived: 90 years)[6][7][8]
# 3   Thomas Jefferson1743–1826(Lived: 83 years)[9][...
# 4   Thomas Jefferson1743–1826(Lived: 83 years)[9][...
# ..                                                ...
# 75    George W. BushBorn 1946(73 years old)[126][127]
# 76    George W. BushBorn 1946(73 years old)[126][127]
# 77      Barack ObamaBorn 1961(58 years old)[128][129]
# 78      Barack ObamaBorn 1961(58 years old)[128][129]
# 79      Donald TrumpBorn 1946(73 years old)[130][131]
#
#                                       Prior office[b]  Party[c]  \
# 0   Commander-in-Chiefof theContinental Army(1775–...       NaN
# 1   Commander-in-Chiefof theContinental Army(1775–...       NaN
# 2   1stvice president of the United States(1789–1797)       NaN
# 3   2ndvice president of the United States(1797–1801)       NaN
# 4   2ndvice president of the United States(1797–1801)       NaN
# ..                                                ...       ...
# 75                   46thgovernor of Texas(1995–2000)       NaN
# 76                   46thgovernor of Texas(1995–2000)       NaN
# 77              U.S. senator from Illinois(2005–2008)       NaN
# 78              U.S. senator from Illinois(2005–2008)       NaN
# 79  Chairman ofthe Trump Organization(1971–2017)(N...       NaN
#
#                Party[c].1 Election  \
# 0         Unaffiliated[2]  1788–89
# 1         Unaffiliated[2]     1792
# 2              Federalist     1796
# 3   Democratic-Republican     1800
# 4   Democratic-Republican     1804
# ..                    ...      ...
# 75             Republican     2000
# 76             Republican     2004
# 77             Democratic     2008
# 78             Democratic     2012
# 79             Republican     2016
#
#                                  Vice President         pres_start  \
# 0                              John Adams[e][f]  April 30, 1789[d]
# 1                              John Adams[e][f]  April 30, 1789[d]
# 2                           Thomas Jefferson[g]      March 4, 1797
# 3       Aaron BurrMarch 4, 1801 – March 4, 1805      March 4, 1801
# 4   George ClintonMarch 4, 1805 – March 4, 1809      March 4, 1801
# ..                                          ...                ...
# 75                                  Dick Cheney   January 20, 2001
# 76                                  Dick Cheney   January 20, 2001
# 77                                    Joe Biden   January 20, 2009
# 78                                    Joe Biden   January 20, 2009
# 79                                   Mike Pence   January 20, 2017
#
#           presy_start
# 0   April 30, 1789[d]
# 1   April 30, 1789[d]
# 2       March 4, 1797
# 3       March 4, 1801
# 4       March 4, 1801
# ..                ...
# 75   January 20, 2001
# 76   January 20, 2001
# 77   January 20, 2009
# 78   January 20, 2009
# 79   January 20, 2017
#
# [80 rows x 11 columns]

# %%
df.head()
# Out:
#    Presidency[a]                  Presidency[a].1  President  \
# 0              1  April 30, 1789[d]–March 4, 1797        NaN
# 1              1  April 30, 1789[d]–March 4, 1797        NaN
# 2              2      March 4, 1797–March 4, 1801        NaN
# 3              3      March 4, 1801–March 4, 1809        NaN
# 4              3      March 4, 1801–March 4, 1809        NaN
#
#                                          President.1  \
# 0  George Washington1732–1799(Lived: 67 years)[3]...
# 1  George Washington1732–1799(Lived: 67 years)[3]...
# 2      John Adams1735–1826(Lived: 90 years)[6][7][8]
# 3  Thomas Jefferson1743–1826(Lived: 83 years)[9][...
# 4  Thomas Jefferson1743–1826(Lived: 83 years)[9][...
#
#                                      Prior office[b]  Party[c]  \
# 0  Commander-in-Chiefof theContinental Army(1775–...       NaN
# 1  Commander-in-Chiefof theContinental Army(1775–...       NaN
# 2  1stvice president of the United States(1789–1797)       NaN
# 3  2ndvice president of the United States(1797–1801)       NaN
# 4  2ndvice president of the United States(1797–1801)       NaN
#
#               Party[c].1 Election  \
# 0        Unaffiliated[2]  1788–89
# 1        Unaffiliated[2]     1792
# 2             Federalist     1796
# 3  Democratic-Republican     1800
# 4  Democratic-Republican     1804
#
#                                 Vice President         pres_start
# 0                             John Adams[e][f]  April 30, 1789[d]
# 1                             John Adams[e][f]  April 30, 1789[d]
# 2                          Thomas Jefferson[g]      March 4, 1797
# 3      Aaron BurrMarch 4, 1801 – March 4, 1805      March 4, 1801
# 4  George ClintonMarch 4, 1805 – March 4, 1809      March 4, 1801

# %%
df['pres_name']=df["President.1"].str.replace(r'\d+.*','')

# %%
df["President.1"].iloc[0]
# Out:
# 'George Washington1732–1799(Lived: 67 years)[3][4][5]'

# %%
def get_years(row):
    import re
    #test='George Washington1732–1799(Lived: 67 years)[3][4][5]'
    test=row["President.1"]
    pattern=r'(?P<birth>\d\d\d\d).(?P<death>\d\d\d\d)'
    m=re.search(pattern,test)
    if m:
        m.groupdict()
        row["birth"]=m["birth"]
        row["death"]=m["death"]
        return row
    else:
        row["birth"]=None
        row["death"]=None
        return row
df.apply(get_years, axis=1)

# %%
df[["real_birth","real_death"]]=df["President.1"].str.extract(r'(?P<birth>\d\d\d\d).(?P<death>\d\d\d\d)')
df
# Out:
#     Presidency[a]                    Presidency[a].1  President  \
# 0               1    April 30, 1789[d]–March 4, 1797        NaN
# 1               1    April 30, 1789[d]–March 4, 1797        NaN
# 2               2        March 4, 1797–March 4, 1801        NaN
# 3               3        March 4, 1801–March 4, 1809        NaN
# 4               3        March 4, 1801–March 4, 1809        NaN
# ..            ...                                ...        ...
# 75             43  January 20, 2001–January 20, 2009        NaN
# 76             43  January 20, 2001–January 20, 2009        NaN
# 77             44  January 20, 2009–January 20, 2017        NaN
# 78             44  January 20, 2009–January 20, 2017        NaN
# 79             45         January 20, 2017–Incumbent        NaN
#
#                                           President.1  \
# 0   George Washington1732–1799(Lived: 67 years)[3]...
# 1   George Washington1732–1799(Lived: 67 years)[3]...
# 2       John Adams1735–1826(Lived: 90 years)[6][7][8]
# 3   Thomas Jefferson1743–1826(Lived: 83 years)[9][...
# 4   Thomas Jefferson1743–1826(Lived: 83 years)[9][...
# ..                                                ...
# 75    George W. BushBorn 1946(73 years old)[126][127]
# 76    George W. BushBorn 1946(73 years old)[126][127]
# 77      Barack ObamaBorn 1961(58 years old)[128][129]
# 78      Barack ObamaBorn 1961(58 years old)[128][129]
# 79      Donald TrumpBorn 1946(73 years old)[130][131]
#
#                                       Prior office[b]  Party[c]  \
# 0   Commander-in-Chiefof theContinental Army(1775–...       NaN
# 1   Commander-in-Chiefof theContinental Army(1775–...       NaN
# 2   1stvice president of the United States(1789–1797)       NaN
# 3   2ndvice president of the United States(1797–1801)       NaN
# 4   2ndvice president of the United States(1797–1801)       NaN
# ..                                                ...       ...
# 75                   46thgovernor of Texas(1995–2000)       NaN
# 76                   46thgovernor of Texas(1995–2000)       NaN
# 77              U.S. senator from Illinois(2005–2008)       NaN
# 78              U.S. senator from Illinois(2005–2008)       NaN
# 79  Chairman ofthe Trump Organization(1971–2017)(N...       NaN
#
#                Party[c].1 Election  \
# 0         Unaffiliated[2]  1788–89
# 1         Unaffiliated[2]     1792
# 2              Federalist     1796
# 3   Democratic-Republican     1800
# 4   Democratic-Republican     1804
# ..                    ...      ...
# 75             Republican     2000
# 76             Republican     2004
# 77             Democratic     2008
# 78             Democratic     2012
# 79             Republican     2016
#
#                                  Vice President         pres_start  \
# 0                              John Adams[e][f]  April 30, 1789[d]
# 1                              John Adams[e][f]  April 30, 1789[d]
# 2                           Thomas Jefferson[g]      March 4, 1797
# 3       Aaron BurrMarch 4, 1801 – March 4, 1805      March 4, 1801
# 4   George ClintonMarch 4, 1805 – March 4, 1809      March 4, 1801
# ..                                          ...                ...
# 75                                  Dick Cheney   January 20, 2001
# 76                                  Dick Cheney   January 20, 2001
# 77                                    Joe Biden   January 20, 2009
# 78                                    Joe Biden   January 20, 2009
# 79                                   Mike Pence   January 20, 2017
#
#               pres_name real_birth real_death
# 0     George Washington       1732       1799
# 1     George Washington       1732       1799
# 2            John Adams       1735       1826
# 3      Thomas Jefferson       1743       1826
# 4      Thomas Jefferson       1743       1826
# ..                  ...        ...        ...
# 75  George W. BushBorn         NaN        NaN
# 76  George W. BushBorn         NaN        NaN
# 77    Barack ObamaBorn         NaN        NaN
# 78    Barack ObamaBorn         NaN        NaN
# 79    Donald TrumpBorn         NaN        NaN
#
# [80 rows x 13 columns]

# %%
df.iloc[69]
# Out:
# Presidency[a]                                                     39
# Presidency[a].1                    January 20, 1977–January 20, 1981
# President                                                        NaN
# President.1        Jimmy CarterBorn 1924(94 years old)[114][115][...
# Prior office[b]                   76thgovernor of Georgia(1971–1975)
# Party[c]                                                         NaN
# Party[c].1                                                Democratic
# Election                                                        1976
# Vice President                                        Walter Mondale
# pres_start                                          January 20, 1977
# pres_name                                          Jimmy CarterBorn
# real_birth                                                       NaN
# real_death                                                       NaN
# Name: 69, dtype: object
