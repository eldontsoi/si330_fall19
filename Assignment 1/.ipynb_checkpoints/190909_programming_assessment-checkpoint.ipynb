# %% [markdown]
# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
# Import pandas library 
import pandas as pd 

# initialize list of lists 
data = [['tom','s','s','a','a','f'],['tom','s','s','a','a','f'],['tom','s','s','a','a','f'],['tom','s','s','a','a','f']]
data2 = [['adsf','s','s','a','t','f'],['asdf','s','s','a','we','f'],['dsf','s','s','s','a','f'],['ds','s','s','a','a','f']]
# # Create the pandas DataFrame 
df1 = pd.DataFrame(data, columns = ['Name', 'Age','c','d','e','f']) 
df2 = pd.DataFrame(data, columns = ['Name', 'y','h','h','q','w']) 
#df
# # print dataframe. 
# df.columns = ['C','A','N','A','D','A']
df3 = df1.set_index([pd.Index([1, 8, 1, 7])])

#df4.shape

df4 = df3.columns.sort_values()
df4
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])
ser1[ser1.isin(ser2)]
# Out:
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# # Assignment 1
# For this assignment you'll be looking at 2017 data on immunizations from the CDC. Your datafile for this assignment is in [datasets/NISPUF17.csv](datasets/NISPUF17.csv). A data users guide for this, which you'll need to map the variables in the data to the questions being asked, is available at [datasets/NIS-PUF17-DUG.pdf](datasets/NIS-PUF17-DUG.pdf).

# %% [markdown]
# ## Question 1 (20%)
# Write a function called `proportion_of_education` which returns the proportion of children in the dataset who had a mother with the education levels equal to less than high school (<12), high school (12), more than high school but not a college graduate (>12) and college degree.
#
# *This function should return a dictionary in the form of (use the correct numbers, do not round numbers):*
# ```
#     {"less than high school":0.2,
#     "high school":0.4,
#     "more than high school but not college":0.2,
#     "college":0.2}
# ```

# %%
import pandas as pd
df = pd.read_csv('NISPUF17.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  SEQNUMC  SEQNUMHH  PDAT    PROVWT_D     RDDWT_D  STRATUM  YEAR  \
# 0           1   128521     12852     2         NaN  235.916956     1031  2017
# 1           2    10741      1074     2         NaN  957.353840     1068  2017
# 2           3   220011     22001     2         NaN  189.611299     1050  2017
# 3           4    86131      8613     1  675.430817  333.447418     1040  2017
# 4           5   227141     22714     1  482.617748  278.768063     1008  2017
#
#    AGECPOXR  HAD_CPOX     ...       XVRCTY2  XVRCTY3  XVRCTY4  XVRCTY5  \
# 0       NaN         2     ...                             NaN      NaN
# 1       NaN         2     ...                             NaN      NaN
# 2       NaN         2     ...                             NaN      NaN
# 3       NaN         2     ...                             NaN      NaN
# 4       NaN         2     ...                             NaN      NaN
#
#    XVRCTY6  XVRCTY7  XVRCTY8  XVRCTY9  INS_STAT2_I  INS_BREAK_I
# ...

# %%
import collections
def proportion_of_education():
    
    EDUC1 = df[['EDUC1']]
    elem = EDUC1.groupby(["EDUC1"]).size()
    sum_elem = EDUC1.groupby(["EDUC1"]).size().sum()

    education_dict = {"less than high school":elem[1]/sum_elem,
                      "high school":elem[2]/sum_elem,
                    "more than high school but not college":elem[3]/sum_elem,
                    "college":elem[4]/sum_elem}

    
    
    return education_dict
proportion_of_education()
# Out:
# {'college': 0.47974705779026877,
#  'high school': 0.172352011241876,
#  'less than high school': 0.10202002459160373,
#  'more than high school but not college': 0.24588090637625154}

# %%
import numpy as np
df.groupby(["EDUC1"]).apply(len)
# Out:
# EDUC1
# 1     2904
# 2     4906
# 3     6999
# 4    13656
# dtype: int64

# %%
# import collections
# def proportion_of_education():
#     import numpy as np
#     groups=df.groupby(["EDUC1"]).agg(len,np.sum)
#     elem = groups.size()
#     sum_elem = groups.sum()

#     education_dict = {"less than high school":elem[1]/sum_elem,
#                       "high school":elem[2]/sum_elem,
#                     "more than high school but not college":elem[3]/sum_elem,
#                     "college":elem[4]/sum_elem}

    
    
#     return education_dict
# proportion_of_education()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3736                 try:
# -> 3737                     assert not args and not kwargs
#    3738                     result = self._aggregate_multiple_funcs(
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _aggregate_generic(self, func, *args, **kwargs)
#    3764                 for name, data in self:
# -> 3765                     result[name] = self._try_cast(func(data, *args, **kwargs),
#    3766                                                   data)
#
# TypeError: len() takes exactly one argument (2 given)
#
# ...

# %%
elem
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c79786215ac5> in <module>()
# ----> 1 elem
#
# NameError: name 'elem' is not defined

# %%
proportion_of_education()
# Out:
# {'college': 0.47974705779026877,
#  'high school': 0.172352011241876,
#  'less than high school': 0.10202002459160373,
#  'more than high school but not college': 0.24588090637625154}

# %%
import pandas as pd
df = pd.read_csv('NISPUF17.csv')

# %%
df[["P_NUMFLU","CBF_01"]].head().groupby("P_NUMFLU").count() #get the unique values of educ1, no repeats, and
# Out:
#    P_NUMFLU  CBF_01
# 0       NaN       1
# 1       NaN       2
# 2       NaN       2
# 3       3.0       2
# 4       0.0       1

# %%
EDUC1 = df[['EDUC1']]
elem = EDUC1.groupby(["EDUC1"]).size()
print(elem)
sum_elem = EDUC1.groupby(["EDUC1"]).size().sum()

education_dict = {"less than high school":elem[1]/sum_elem,
                  "high school":elem[2]/sum_elem,
                "more than high school but not college":elem[3]/sum_elem,
                "college":elem[4]/sum_elem}

#education_dict
# Out:
# EDUC1
# 1     2904
# 2     4906
# 3     6999
# 4    13656
# dtype: int64

# %%
education_dict = {"less than high school":elem[1]/sum_elem}

# %%
education_dict
# Out:
# {'less than high school': 0.10202002459160373}

# %%
elem[1]/sum_elem
# Out:
# 0.10202002459160373

# %%
count = 0
for i in EDUC1:
    print('lol')
    if (EDUC1 is 4):
        count += 1
count
# Out:
# lol
# 0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-faf70d71ac2c> in <module>()
# ----> 1 count(EDUC1 == 4)
#
# TypeError: 'int' object is not callable

# %%
df = pd.DataFrame({'a':list('abssbab')})

count = df.count('a')
count
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-0249030e7bf6> in <module>()
#       1 df = pd.DataFrame({'a':list('abssbab')})
#       2
# ----> 3 count = df.count('a')
#       4 count
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in count(self, axis, level, numeric_only)
#    5628         count : Series (or DataFrame if level specified)
#    5629         """
# -> 5630         axis = self._get_axis_number(axis)
#    5631         if level is not None:
#    5632             return self._count_level(level, axis=axis,
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     355                 pass
#     356         raise ValueError('No axis named {0} for object type {1}'
# --> 357                          .format(axis, type(self)))
#     358
#     359     def _get_axis_name(self, axis):
#
# ...

# %%
education_proportion = {}

type(education_proportion)
# Out:
# dict

# %%
assert type(proportion_of_education())==type({}), "You must return a dictionary."
assert len(proportion_of_education()) == 4, "You have not returned a dictionary with four items in it."
assert "less than high school" in proportion_of_education().keys(), "You have not returned a dictionary with the correct keys."
assert "high school" in proportion_of_education().keys(), "You have not returned a dictionary with the correct keys."
assert "more than high school but not college" in proportion_of_education().keys(), "You have not returned a dictionary with the correct keys."
assert "college" in proportion_of_education().keys(), "You have not returned a dictionary with the correct keys."

# %% [markdown]
# ## Question 2 (20%)
#
# Let's explore the relationship between being fed breastmilk as a child and getting a seasonal influenza vaccine from a healthcare provider. Return a tuple of the average number of influenza vaccines for those children we know received breastmilk as a child and those who know did not.
#
# *This function should return a tuple in the form (use the correct numbers:*
# ```
# (2.5, 0.1)
# ```

# %%
def average_influenza_doses():
    # your code goes here
    new_df = df[['P_NUMFLU','CBF_01']].dropna().groupby('CBF_01').mean()
    
    tuple_influenza = (float(new_df.iloc[0]),float(new_df.iloc[1]))
    print(tuple_influenza)
    return tuple_influenza

# %%
tuple_influenza =(df[['P_NUMFLU','CBF_01']].dropna().groupby('CBF_01').mean().iloc[0],df[['P_NUMFLU','CBF_01']].dropna().groupby('CBF_01').mean().iloc[1])

#tuple_influenza = (float(new_df.iloc[0]),float(new_df.iloc[1]))
print(tuple_influenza)
# Out:
# (P_NUMFLU    1.879919
# Name: 1, dtype: float64, P_NUMFLU    1.596395
# Name: 2, dtype: float64)

# %%
average_influenza_doses()
# Out:
# (1.8799187420058687, 1.5963945918878317)

# %%
#return tuple, avg number of influenza vaccines & recieved breastmilk
#return tuple, avg number of influenza vaccines & did not recieved breastmilk
#1234 bf - 1 = yes, 2 = no

# %%
df.where
# Out:
#        Unnamed: 0  SEQNUMC  SEQNUMHH  PDAT    PROVWT_D      RDDWT_D  STRATUM  \
# 0               1   128521     12852     2         NaN   235.916956     1031
# 1               2    10741      1074     2         NaN   957.353840     1068
# 2               3   220011     22001     2         NaN   189.611299     1050
# 3               4    86131      8613     1  675.430817   333.447418     1040
# 4               5   227141     22714     1  482.617748   278.768063     1008
# 5               6   207941     20794     2         NaN    35.995367     1019
# 6               7   221381     22138     1  516.427723   248.916038     1008
# 7               8   182861     18286     1  313.225832   163.213401     1001
# 8               9   161121     16112     1  978.042448   718.616990     1016
# 9              10   143401     14340     2         NaN  1536.859533     1068
# 10             11   128211     12821     1  335.398714   198.123294     1057
# ...

# %%
new_df
# Out:
#         P_NUMFLU
# CBF_01
# 1       1.879919
# 2       1.596395
# 77      1.380952
# 99      1.000000

# %%
new_df = df[['P_NUMFLU','CBF_01']].dropna().groupby('CBF_01').mean()
new_df.iloc[1]
new_df.iloc[0]
tuple_influenza = (float(new_df.iloc[0]),float(new_df.iloc[1]))
# subset = new_df[[ 'CBF_01']]
# tuples = [tuple(x) for x in subset[0]]
tuple_influenza
# for n in new_df.itertuples():
#     print(n)
# Out:
# (1.8799187420058687, 1.5963945918878317)

# %%
tuples
# Out:
# [(6131,), (2488,), (4608,), (5978,), (1571,), (37,), (3,)]

# %%
assert len(average_influenza_doses())==2, "Return two values in a tuple, the first for yes and the second for no."
# Out:
# (1.8799187420058687, 1.5963945918878317)

# %% [markdown]
# ## Question 3 (25%)
# It would be interesting to see if there is any evidence of a link between vaccine effectiveness and sex of the child. Calculate the ratio of the number of children who contracted chickenpox but were vaccinated against it (at least one varicella dose) versus those who were vaccinated and did not contract chicken pox. Return results by sex.
#
# *This function should return a dictionary in the form of (use the correct numbers):*
# ```
#     {"male":0.2,
#     "female":0.4}
# ```
#
# Note: To aid in verification, the `chickenpox_by_sex()['female']` value I'm looking for starts with the digits `0.00773`.

# %%
assert len(chickenpox_by_sex())==2, "Return a dictionary with two items, the first for males and the second for females."
# Out:
# {'male': 0.009676960296001139, 'female': 0.0077918259335489565}

# %% [markdown]
# sex: 1 = male, 2 = female
# had_cpox: 1 = yes, 2 = no, ... don't know, refuse, missing
# p_numvrc (doses): 0 = not vaccinated, <0 = vaccinated

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('NISPUF17.csv')
cpox = df[["HAD_CPOX","SEX",'P_NUMVRC']]#.loc[(df['HAD_CPOX'] == 1)]
male = cpox.where(cpox['SEX'] == 1).dropna() #filter only by male
female = cpox.where(cpox['SEX'] == 2).dropna() #filter only by female

male_had_cpox = male.where(male['HAD_CPOX'] == 1).dropna() #children with cpox
male_no_cpox = male.where(male['HAD_CPOX'] != 1).dropna()#whithout cpox
male_yes_cpox_vaccinated = male_had_cpox.where(male_had_cpox['P_NUMVRC'] > 0).dropna()
male_no_cpox_vaccinated = male_no_cpox.where(male_no_cpox['P_NUMVRC'] > 0).dropna()
count_yes = male_yes_cpox_vaccinated.groupby(['HAD_CPOX','SEX']).size().to_frame("count").reset_index()
count_yes['count']
count_no = male_no_cpox_vaccinated.groupby(['HAD_CPOX','SEX']).size().to_frame("count").reset_index()
count_no['count']
male_ratio = count_yes/count_no
male_ratio['count'][0]
# male_had_cpox_vaccinated = (cpox.where(cpox['SEX'] == 1).where(cpox['HAD_CPOX'] == 1).where(cpox['P_NUMVRC'] > 0).dropna() / 
#                             cpox.where(cpox['SEX'] == 1).where(cpox['HAD_CPOX'] == 0).where(cpox['P_NUMVRC'] > 0).dropna())
# male_had_cpox_vaccinated
# Out:
# 0.009675583380762664

# %%
def chickenpox_by_sex():
    import pandas as pd
    import numpy as np
    df = pd.read_csv('NISPUF17.csv')
    
    df = pd.read_csv('NISPUF17.csv')
    cpox = df[["HAD_CPOX","SEX",'P_NUMVRC']]#.loc[(df['HAD_CPOX'] == 1)]
    male = cpox.where(cpox['SEX'] == 1).dropna() #filter only by male
    female = cpox.where(cpox['SEX'] == 2).dropna() #filter only by female

    male_had_cpox = male.where(male['HAD_CPOX'] == 1).dropna() #children with cpox
    male_no_cpox = male.where(male['HAD_CPOX'] != 1).dropna()#whithout cpox
    male_yes_cpox_vaccinated = male_had_cpox.where(male_had_cpox['P_NUMVRC'] > 0).dropna()
    male_no_cpox_vaccinated = male_no_cpox.where(male_no_cpox['P_NUMVRC'] > 0).dropna()
    count_yes = male_yes_cpox_vaccinated.groupby(['HAD_CPOX','SEX']).size().to_frame("count").reset_index()
    count_yes['count']
    count_no = male_no_cpox_vaccinated.groupby(['HAD_CPOX','SEX']).size().to_frame("count").reset_index()
    count_no['count']
    male_ratio = count_yes/count_no
    
    male_ratio = male_ratio['count'][0]
    
    df2 = df[["HAD_CPOX","SEX",'P_NUMVRC']].dropna() #drop not a number
    df3 = df2.loc[(df2["P_NUMVRC"] == 1)|(df2["P_NUMVRC"] == 2)]
    #df2[df2['P_NUMVRC'] != 0]  #remove the 0s
    df4 = df3.groupby(["HAD_CPOX","SEX"]).size().to_frame("count").reset_index() #convert series to df

    female_cpox = (df4.loc[(df4["SEX"] == 2)&(df4["HAD_CPOX"] == 1), ["count"]]).iloc[0].item() ##what is iloc and item
    female_no_cpox = (df4.loc[(df4["SEX"] == 2)&(df4["HAD_CPOX"] == 2), ["count"]]).iloc[0].item() 

    print({'male':male_ratio,'female':female_cpox / female_no_cpox    })
    dict_cpox = {'male':male_ratio,'female':female_cpox / female_no_cpox    }
    return dict_cpox

# %%
def chickenpox_by_sex():
    import pandas as pd
    import numpy as np
    df = pd.read_csv('NISPUF17.csv')
    df2 = df[["HAD_CPOX","SEX",'P_NUMVRC']].dropna() #drop not a number
    df3 = df2.loc[(df2["P_NUMVRC"] == 1)|(df2["P_NUMVRC"] == 2)]
    #df2[df2['P_NUMVRC'] != 0]  #remove the 0s
    df4 = df3.groupby(["HAD_CPOX","SEX"]).size().to_frame("count").reset_index() #convert series to df


    male_cpox =(df4.loc[(df4["SEX"] == 1)&(df4["HAD_CPOX"] == 1), ["count"]]).iloc[0].item() ##what is iloc and item
    male_no_cpox = (df4.loc[(df4["SEX"] == 1)&(df4["HAD_CPOX"] == 2), ["count"]]).iloc[0].item() 

    female_cpox = (df4.loc[(df4["SEX"] == 2)&(df4["HAD_CPOX"] == 1), ["count"]]).iloc[0].item() ##what is iloc and item
    female_no_cpox = (df4.loc[(df4["SEX"] == 2)&(df4["HAD_CPOX"] == 2), ["count"]]).iloc[0].item() 

    print({'male':male_cpox/male_no_cpox,'female':female_cpox / female_no_cpox    })
    dict_cpox = {'male':male_cpox/male_no_cpox,'female':female_cpox / female_no_cpox    }
    return dict_cpox

# %% [markdown]
# HAD_CPOX – did child ever have chicken pox
# (introduced in 2005; I_HADCPX used through 2004)
# Yes
# No
# Don’t know
# Refused
# Missing
#
# SEX – sex of child
# Male
# Female
#
# vacinnated (at least one dose) vs not vacinnated (no does)

# %%
df2 = df[["HAD_CPOX","SEX",'P_NUMVRC']].dropna() #drop not a number
df3 = df2.loc[((df2["P_NUMVRC"] == 1)|(df2["P_NUMVRC"] == 2))]
df5 = df4.groupby(["HAD_CPOX","SEX"]).size().to_frame("count").reset_index() #convert series to df


male_cpox =(df5.loc[(df5["SEX"] == 1)&(df5["HAD_CPOX"] == 1), ["count"]]).iloc[0].item() ##what is iloc and item
male_no_cpox = (df5.loc[(df5["SEX"] == 1)&(df5["HAD_CPOX"] == 2), ["count"]]).iloc[0].item() 

female_cpox = (df5.loc[(df5["SEX"] == 2)&(df5["HAD_CPOX"] == 1), ["count"]]).iloc[0].item() ##what is iloc and item
female_no_cpox = (df5.loc[(df5["SEX"] == 2)&(df5["HAD_CPOX"] == 2), ["count"]]).iloc[0].item() 

print({'male':male_cpox/male_no_cpox,'female':female_cpox / female_no_cpox    })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2fdb97757c6a> in <module>()
#       1 df2 = df[["HAD_CPOX","SEX",'P_NUMVRC']].dropna() #drop not a number
#       2 df3 = df2.loc[((df2["P_NUMVRC"] == 1)|(df2["P_NUMVRC"] == 2))]
# ----> 3 df5 = df4.groupby(["HAD_CPOX","SEX"]).size().to_frame("count").reset_index() #convert series to df
#       4
#       5
#
# NameError: name 'df4' is not defined

# %%
df.loc[(df["HAD_CPOX"] == 4)]
# Out:
# Empty DataFrame
# ...

# %%
male_cpox
# Out:
# 97

# %%
df[['P_NUMVRC']].dropna()
# Out:
#        P_NUMVRC
# 3           1.0
# 4           0.0
# 6           1.0
# 7           0.0
# 8           0.0
# 10          1.0
# 12          1.0
# 16          2.0
# 19          1.0
# 20          1.0
# 21          1.0
# 22          1.0
# 24          1.0
# 25          1.0
# 26          1.0
# 27          1.0
# 28          1.0
# 29          1.0
# 30          1.0
# 34          1.0
# 35          1.0
# 36          0.0
# 39          1.0
# 40          1.0
# 41          1.0
# 43          1.0
# 44          1.0
# 46          1.0
# 47          1.0
# 49          1.0
# ...         ...
# 28397       1.0
# 28398       0.0
# 28400       1.0
# 28402       1.0
# 28403       1.0
# 28404       1.0
# 28406       1.0
# 28407       1.0
# 28408       0.0
# 28409       1.0
# 28410       1.0
# 28411       1.0
# 28412       1.0
# 28415       1.0
# 28418       1.0
# 28422       1.0
# 28424       1.0
# 28425       1.0
# 28427       1.0
# 28430       1.0
# 28435       1.0
# 28436       1.0
# 28437       1.0
# ...

# %%
new_df = df.loc[(df['HAD_CPOX'] == 3)|(df['HAD_CPOX'] == 4)].groupby('HAD_CPOX').sum()
new_df
# Out:
# Empty DataFrame
# ...

# %%
df2
# Out:
#        HAD_CPOX  SEX  P_NUMVRC
# 3             2    2       1.0
# 4             2    2       0.0
# 6             2    2       1.0
# 7             2    2       0.0
# 8             1    1       0.0
# 10            2    1       1.0
# 12            2    1       1.0
# 16            2    1       2.0
# 19            2    1       1.0
# 20            2    2       1.0
# 21            2    1       1.0
# 22            2    2       1.0
# 24            2    2       1.0
# 25            2    2       1.0
# 26            2    2       1.0
# 27            2    1       1.0
# 28            2    2       1.0
# 29            2    1       1.0
# 30            2    1       1.0
# 34            2    1       1.0
# 35            2    2       1.0
# 36            2    1       0.0
# 39            2    1       1.0
# 40            2    2       1.0
# 41            2    1       1.0
# 43            2    1       1.0
# 44            2    2       1.0
# 46            2    1       1.0
# 47            2    2       1.0
# ...

# %%
# Out:
#     SEX  HAD_CPOX  P_NUMVRC
# 3     2         2       1.0
# 4     2         2       0.0
# 6     2         2       1.0
# 7     2         2       0.0
# 8     1         1       0.0
# 10    1         2       1.0
# 12    1         2       1.0
# 16    1         2       2.0
# 19    1         2       1.0
# 20    2         2       1.0

# %% [markdown]
# ## Question 4 (25%)
# A correlation is a statistical relationship between two variables. If we wanted to know if vaccines work, we might look at the correlation between the use of the vaccine and whether it results in prevention of the infection or disease [1]. In this question, you are to see if there is a correlation between having had the chicken pox and the number of chickenpox vaccine doses given (varicella).
#
# Some notes on interpreting the answer. If the `had_chickenpox_column` is either `1` (for yes) or `2` for no, and that the `num_chickenpox_vaccine_column` is the number of doses a child has been given of the varicella vaccine, then a positive correlation (e.g. `corr > 0`) would mean that an increase in `had_chickenpox_column` (which means more no's) would mean an increase in the `num_chickenpox_vaccine_column` (which means more doses of vaccine). If `corr < 0` then there is a negative correlation, indicating that having had chickenpox is related to an increase in the number of vaccine doses. Also, `pval` refers to the probability the relationship observed is significant. In this case `pval` should be very very small (will end in `e-18` indicating a very small number), which means the result unlikely to be by chance.
#
# [1] This isn't really the full picture, since we are not looking at when the dose was given. It's possible that children had chickenpox and then their parents went to get them the vaccine. Does this dataset have the data we would need to investigate the timing of the dose?

# %%
df1 = df[["P_NUMVRC","HAD_CPOX"]].dropna()
df2 = df1.loc[(df1["HAD_CPOX"] == 1)|(df["HAD_CPOX"] == 2)]
df3 = df2.rename(columns= {"P_NUMVRC":"num_chickenpox_vaccine_column", "HAD_CPOX":"had_chickenpox_column"})
corr, pval=stats.pearsonr(df3["had_chickenpox_column"],df3["num_chickenpox_vaccine_column"])

# %%
print(corr)
# Out:
# 0.07044873460148

# %%
def corr_chickenpox():
    import scipy.stats as stats
    import numpy as np
    import pandas as pd
    
    # this is just an example dataframe    
    df1 = df[["P_NUMVRC","HAD_CPOX"]].dropna()
    df2 = df1.loc[(df1["HAD_CPOX"] == 1)|(df["HAD_CPOX"] == 2)]
    df3 = df2.rename(columns= {"P_NUMVRC":"num_chickenpox_vaccine_column", "HAD_CPOX":"had_chickenpox_column"})
    
    # here is some stub code to actually run the correlation
    corr, pval=stats.pearsonr(df3["had_chickenpox_column"],df3["num_chickenpox_vaccine_column"])
    
    # just return the correlation at the end
    # return corr
    print(corr_chickenpox())

# %%
def corr_chickenpox():
    import scipy.stats as stats
    import numpy as np
    import pandas as pd
    
    df1 = df[["P_NUMVRC","HAD_CPOX"]].dropna()
    df2 = df1.loc[(df1["HAD_CPOX"] == 1)|(df["HAD_CPOX"] == 2)]
    df3 = df2.rename(columns= {"P_NUMVRC":"num_chickenpox_vaccine_column", "HAD_CPOX":"had_chickenpox_column"})
    corr, pval=stats.pearsonr(df3["had_chickenpox_column"],df3["num_chickenpox_vaccine_column"])
    return (corr)

# %%
corr_chickenpox()
# Out:
# 0.07044873460148

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd

# this is just an example dataframe
df=pd.DataFrame({"HAD_CPOX":np.random.randint(1,3,size=(100)),
               "P_NUMVRC":np.random.randint(0,6,size=(100))})

# here is some stub code to actually run the correlation
corr, pval=stats.pearsonr(df["HAD_CPOX"],df["P_NUMVRC"])

# just return the correlation at the end
# return corr

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd

# %%
assert -1<=corr_chickenpox()<=1, "You must return a float number between -1.0 and 1.0."

# %% [markdown]
# ## Question 5 (10%)
#
# Is there a relationship between states which voted for the republican candidate for president in 2016 (Trump) versus those who voted for the democratic candidate for president in 2016 (Hillary) and the rate of vaccination in those states in 2017? I would like you to answer this by doing a correlation test between the ratio of votes for Trump/Clinton against the ratio of Vaccination/Non-Vaccination (of Chickenpox!) by state.
#
# Note: You are certainly using joins or merges here.
#
# Note: You will might need the state [FIPS identifiers](https://en.wikipedia.org/wiki/Federal_Information_Processing_Standard_state_code#FIPS_state_codes) and will certainly want the [MIT Elections Data](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/42MVDX) which has the results from 2018.
#
# Note: I don't know the answer to this question already.

# %%
df_no_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] == 0].groupby(["STATE"]).rename(columns= {"STATE":"state", "count":"no_vaccine"}) #get no vaccine data.size().to_frame("count").reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e6986c247079> in <module>()
# ----> 1 df_no_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] == 0].groupby(["STATE"]).rename(columns= {"STATE":"state", "count":"no_vaccine"}) #get no vaccine data.size().to_frame("count").reset_index()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in __getattr__(self, attr)
#     671             return self[attr]
#     672         if hasattr(self.obj, attr):
# --> 673             return self._make_wrapper(attr)
#     674
#     675         raise AttributeError("%r object has no attribute %r" %
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _make_wrapper(self, name)
#     685                    "using the 'apply' method".format(kind, name,
#     686                                                      type(self).__name__))
# ...

# %%
df_president = pd.read_csv('1976-2016-president.csv')
df_president.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# 1             Ford, Gerald                  republican    False
# 2           Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin ""Ben""                 prohibition    False
# 4                Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes
# 0          659170     1182850  20171015    NaN
# ...

# %%
#correct code
import scipy.stats as stats
import numpy as np
import pandas as pd
df_president = pd.read_csv('1976-2016-president.csv')
df_vaccine = pd.read_csv('NISPUF17.csv')

df_president = df_president[['state','candidate','candidatevotes','state_fips','year']]
                
df_president = df_president[df_president['year'] == 2016]
df_president = (df_president.loc[df_president['candidate']
                                 .isin(['Trump, Donald J.','Clinton, Hillary'])])
                     
df_president = (df_president.groupby(['state_fips','candidate'])['candidatevotes']
                .sum()
                .unstack())

merge_votes = df_president.reset_index()

merge_votes = merge_votes.rename(columns= {"state_fips":"STATE"})
merge_votes['ratio'] = merge_votes['Trump, Donald J.'] / merge_votes['Clinton, Hillary'] 

df_vaccine = pd.read_csv('NISPUF17.csv', delimiter = ',')
state_vaccine = df_vaccine[["STATE","P_NUMVRC"]].dropna()
no_vac = (state_vaccine[state_vaccine.P_NUMVRC == 0]
          .groupby(["STATE"])
          .count())

yes_vac = (state_vaccine[(state_vaccine.P_NUMVRC >= 1) 
                         & (state_vaccine.P_NUMVRC < 77 )]
           .groupby(["STATE"])
           .count())

merge_vac = (yes_vac
             .merge(no_vac, left_index=True, right_index=True)
             .reset_index())
merge_vac['ratio'] = merge_vac['P_NUMVRC_x'] / merge_vac['P_NUMVRC_y']


corr, pval=stats.pearsonr(merge_votes['ratio'],merge_vac['ratio'])

corr
# Out:
# -0.28010835423617825

# %%
#closer to real answer version

# %matplotlib inline
import scipy.stats as stats
import numpy as np
import pandas as pd
df_president = pd.read_csv('1976-2016-president.csv')
df_vaccine = pd.read_csv('NISPUF17.csv')

#voting data
df_president = (df_president[['state_fips','candidate','candidatevotes','party','writein']]
                .dropna()
                .loc[df_president['year'] == 2016]) #get useful columns and year 2016
trump_votes = (df_president
               .loc[(df_president['candidate'] == 'Trump, Donald J.')& ~(df_president["writein"])]
               .loc[df_president['party'] == 'republican']) #Get trump, clean up party column and writein column
clinton_votes = (df_president
                 .loc[(df_president['candidate'] == 'Clinton, Hillary')& ~(df_president["writein"])]
                 .loc[df_president['party'] == 'democrat']) #likewise
trump_clinton_votes = pd.merge(trump_votes, clinton_votes, on = "state_fips") #merge
trump_clinton_votes['ratio'] = (trump_clinton_votes['candidatevotes_x'])/trump_clinton_votes['candidatevotes_y'] #ratio

#vaccine data
df_vaccine = df_vaccine[["STATE","P_NUMVRC"]]#get two useful columns
df_no_vaccine = (df_vaccine [df_vaccine['P_NUMVRC'] == 0]
                 .groupby(["STATE"])
                 .size()
                 .to_frame("count")
                 .reset_index()
                 .rename(columns= {"STATE":"state", "count":"no_vaccine"})) #get no vaccine data
df_yes_vaccine = (df_vaccine [df_vaccine['P_NUMVRC'] >= 1]
                  .groupby(["STATE"])
                  .size()
                  .to_frame("count")
                  .reset_index()
                  .rename(columns= {"STATE":"state", "count":"yes_vaccine"})) #get yes vaccine data
merge_vaccine = pd.merge(df_no_vaccine,df_yes_vaccine , on = "state") #merge
ratio_vaccine = merge_vaccine['yes_vaccine']/(( merge_vaccine['no_vaccine']))
corr, pval=stats.pearsonr(trump_clinton_votes['ratio'],ratio_vaccine)
corr
# Out:
# -0.2790809695271168

# %%
merge_vac
# Out:
#     STATE  P_NUMVRC_x  P_NUMVRC_y      ratio
# 0       1         273          22  12.409091
# 1       2         212          39   5.435897
# 2       4         242          23  10.521739
# 3       5         234          24   9.750000
# 4       6         302          22  13.727273
# 5       8         232          32   7.250000
# 6       9         253          13  19.461538
# 7      10         216          16  13.500000
# 8      11         257          12  21.416667
# 9      12         282          32   8.812500
# 10     13         277          22  12.590909
# 11     15         210          26   8.076923
# 12     16         178          20   8.900000
# 13     17         439          34  12.911765
# 14     18         220          36   6.111111
# 15     19         208          18  11.555556
# 16     20         168          24   7.000000
# 17     21         214          15  14.266667
# 18     22         256          26   9.846154
# 19     23         241          30   8.033333
# ...

# %%
#correct code
df_vaccine = pd.read_csv('NISPUF17.csv', delimiter = ',')
state_vaccine = df_vaccine[["STATE","P_NUMVRC"]].dropna()
no_vac = (state_vaccine[state_vaccine.P_NUMVRC == 0]
          .groupby(["STATE"])
          .count())
yes_vac = (state_vaccine[(state_vaccine.P_NUMVRC >= 1) 
                         & (state_vaccine.P_NUMVRC < 77 )]
           .groupby(["STATE"])
           .count())

merge_vac = (yes_vac
             .merge(no_vac, left_index=True, right_index=True)
             .reset_index())
merge_vac['ratio'] = merge_vac['P_NUMVRC_x'] / merge_vac['P_NUMVRC_y']

merge_vac

corr, pval=stats.pearsonr(merge_votes['ratio'],merge_vac['ratio'])

corr
#keep getting key error
# Out:
# -0.28010835423617825

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd
df_president = pd.read_csv('1976-2016-president.csv')
df_president = (df_president[['state','candidate','candidatevotes','state_fips']]
                .loc[df_president['year'] == 2016]
                .loc[(df_president['candidate'] == 'Trump, Donald J.')|
                     (df_president['candidate'] == 'Clinton, Hillary')])
trump = df_president.loc[(df_president['candidate'] == 'Trump, Donald J.')]#.sum().unstack()
clinton = df_president.loc[(df_president['candidate'] == 'Clinton, Hillary')]
merge_votes = pd.merge(trump,clinton , how ="outer", on="state_fips")
merge_votes['ratio'] = merge_votes['candidatevotes_x'] / merge_votes['candidatevotes_y'] 
merge_votes = merge_votes.rename(columns= {"state_fips":"STATE"})
votes_vac = pd.merge(merge_votes,merge_vac , how ="outer", on="STATE")
#corr, pval=stats.pearsonr(votes_vac['ratio_x'],votes_vac['ratio_y'])
#votes_vac['ratios'] = votes_vac['ratio_x'] / votes_vac['ratio_y']
#df_president2.columns
votes_vac
# Out:
#                  state_x       candidate_x  candidatevotes_x  STATE  \
# 0                Alabama  Trump, Donald J.           1318255      1
# 1                 Alaska  Trump, Donald J.            163387      2
# 2                Arizona  Trump, Donald J.           1252401      4
# 3               Arkansas  Trump, Donald J.            684872      5
# 4             California  Trump, Donald J.           4483810      6
# 5               Colorado  Trump, Donald J.           1202484      8
# 6            Connecticut  Trump, Donald J.            673215      9
# 7               Delaware  Trump, Donald J.            185127     10
# 8   District of Columbia  Trump, Donald J.             12723     11
# 9                Florida  Trump, Donald J.           4617886     12
# 10               Georgia  Trump, Donald J.           2089104     13
# 11                Hawaii  Trump, Donald J.            128847     15
# 12                 Idaho  Trump, Donald J.            409055     16
# ...

# %%
votes_vac
# Out:
#     STATE                 state  Clinton, Hillary  Trump, Donald J.  \
# 0       1               Alabama            729547           1318255
# 1       2                Alaska            116454            163387
# 2       4               Arizona           1161167           1252401
# 3       5              Arkansas            380494            684872
# 4       6            California           8753788           4483810
# 5       8              Colorado           1338870           1202484
# 6       9           Connecticut            897572            673215
# 7      10              Delaware            235603            185127
# 8      11  District of Columbia            282830             12723
# 9      12               Florida           4504975           4617886
# 10     13               Georgia           1877963           2089104
# 11     15                Hawaii            266891            128847
# 12     16                 Idaho            189765            409055
# ...

# %%
votes_vac = pd.merge(merge_votes,merge_vac , how ="outer", on="STATE")
corr, pval=stats.pearsonr(votes_vac['ratio_x'],votes_vac['ratio_y'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ratio_x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-4c8cbf6641c3> in <module>()
# ...

# %%
corr
# Out:
# 0.3452748700517866

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd
df_president = pd.read_csv('1976-2016-president.csv')
df_vaccine = pd.read_csv('NISPUF17.csv')
#df_president.head()
df_president = (df_president[['state','candidate','candidatevotes','state_fips']]
                .loc[df_president['year'] == 2016]
                .loc[(df_president['candidate'] == 'Trump, Donald J.')|
                     (df_president['candidate'] == 'Clinton, Hillary')]).reset_index(drop = True).set_index('state_fips')
#dangerous - look at source code
def test (x):
    #print((x['candidatevotes']))
    return x['candidatevotes']
df_president = df_president.groupby(['state_fips','state','candidate']).apply(test)#['candidatevotes'].sum().unstack()
#df_president['ratio'] = df_president['Clinton, Hillary']/df_president['Trump, Donald J.']
#df_president#.columns

# %%
votes_vac
# Out:
#     STATE                 state  Clinton, Hillary  Trump, Donald J.  \
# 0       1               Alabama            729547           1318255
# 1       2                Alaska            116454            163387
# 2       4               Arizona           1161167           1252401
# 3       5              Arkansas            380494            684872
# 4       6            California           8753788           4483810
# 5       8              Colorado           1338870           1202484
# 6       9           Connecticut            897572            673215
# 7      10              Delaware            235603            185127
# 8      11  District of Columbia            282830             12723
# 9      12               Florida           4504975           4617886
# 10     13               Georgia           1877963           2089104
# 11     15                Hawaii            266891            128847
# 12     16                 Idaho            189765            409055
# ...

# %%
#df_president.head()

df_vaccine = df_vaccine[["STATE","P_NUMVRC"]]#get two useful columns
df_no_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] == 0].groupby(["STATE"]).size().to_frame("count").reset_index().rename(columns= {"STATE":"state", "count":"no_vaccine"}) #get no vaccine data
df_yes_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] >= 1].groupby(["STATE"]).size().to_frame("count").reset_index().rename(columns= {"STATE":"state", "count":"yes_vaccine"}) #get yes vaccine data
merge_vaccine = pd.merge(df_no_vaccine,df_yes_vaccine , on = "state") #merge
ratio_vaccine = merge_vaccine['yes_vaccine']/(( merge_vaccine['no_vaccine'])+(merge_vaccine['yes_vaccine']))
corr, pval=stats.pearsonr(trump_clinton_votes['ratio'],ratio_vaccine)

df=pd.DataFrame({"ratio of trump/clinton":df_president['ratio'], #plot dataframe
                 "ratio of vaccinated/non":ratio_vaccine})
df.plot() #plots a fancy graph   
# just return the correlation at the end
return corr, pval
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0e3d9db9df7d> in <module>()
#      18 merge_vaccine = pd.merge(df_no_vaccine,df_yes_vaccine , on = "state") #merge
#      19 ratio_vaccine = merge_vaccine['yes_vaccine']/(( merge_vaccine['no_vaccine'])+(merge_vaccine['yes_vaccine']))
# ---> 20 corr, pval=stats.pearsonr(trump_clinton_votes['ratio'],ratio_vaccine)
#      21
#      22 df=pd.DataFrame({"ratio of trump/clinton":df_president['ratio'], #plot dataframe
#
# NameError: name 'trump_clinton_votes' is not defined

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
df_president2 = df_president.reset_index()
#df_president2.rename(columns= {"state_fips":"STATE"})
df_president2.rename({'state_fips':'STATE'}, axis='columns',inplace=True)
df_president2 = df_president2['ratio']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-46cb6e100870> in <module>()
# ----> 1 df_president2 = df_president.reset_index()
#       2 #df_president2.rename(columns= {"state_fips":"STATE"})
#       3 df_president2.rename({'state_fips':'STATE'}, axis='columns',inplace=True)
#       4 df_president2 = df_president2['ratio']
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/series.py in reset_index(self, level, drop, name, inplace)
#    1048         else:
#    1049             df = self.to_frame(name)
# -> 1050             return df.reset_index(level=level, drop=drop)
#    1051
#    1052     def __unicode__(self):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    3377                 # to ndarray and maybe infer different dtype
# ...

# %%
# %matplotlib inline
def corr_election():
    import scipy.stats as stats
    import numpy as np
    import pandas as pd
    df_president = pd.read_csv('1976-2016-president.csv')
    df_vaccine = pd.read_csv('NISPUF17.csv')
    
    df_president = df_president[['state_fips','candidate','candidatevotes','party','writein']].dropna().loc[df_president['year'] == 2016] #get useful columns and year 2016
    trump_votes = df_president.loc[(df_president['candidate'] == 'Trump, Donald J.')& ~(df_president["writein"])].loc[df_president['party'] == 'republican'] #Get trump, clean up party column and writein column
    clinton_votes = df_president.loc[(df_president['candidate'] == 'Clinton, Hillary')& ~(df_president["writein"])].loc[df_president['party'] == 'democrat'] #likewise
    trump_clinton_votes = pd.merge(trump_votes, clinton_votes, on = "state_fips") #merge
    trump_clinton_votes['ratio'] = (trump_clinton_votes['candidatevotes_x'])/trump_clinton_votes['candidatevotes_y'] #ratio
    
    df_vaccine = df_vaccine[["STATE","P_NUMVRC"]]#get two useful columns
    df_no_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] == 0].groupby(["STATE"]).size().to_frame("count").reset_index().rename(columns= {"STATE":"state", "count":"no_vaccine"}) #get no vaccine data
    df_yes_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] >= 1].groupby(["STATE"]).size().to_frame("count").reset_index().rename(columns= {"STATE":"state", "count":"yes_vaccine"}) #get yes vaccine data
    merge_vaccine = pd.merge(df_no_vaccine,df_yes_vaccine , on = "state") #merge
    ratio_vaccine = merge_vaccine['yes_vaccine']/(( merge_vaccine['no_vaccine'])+(merge_vaccine['yes_vaccine']))
    corr, pval=stats.pearsonr(trump_clinton_votes['ratio'],ratio_vaccine)
    
    df=pd.DataFrame({"ratio of trump/clinton":trump_clinton_votes['ratio'], #plot dataframe
                     "ratio of vaccinated/non":ratio_vaccine})
    df.plot() #plots a fancy graph   
    # just return the correlation at the end
    return corr, pval

# %%
corr_election()
# Out:
# (-0.2601154923758659, 0.0652680729771062)

# %%
# %matplotlib inline
def corr_election():
    import scipy.stats as stats
    import numpy as np
    import pandas as pd
    
    
    df.plot()    
    # here is some stub code to actually run the correlation
    corr, pval=stats.pearsonr(df["ratio of trump/clinton"],df["ratio of vaccinated/non"])
    
    # just return the correlation at the end
#clos    return corr, pval

# %%
#closer to real answer version

# %matplotlib inline
import scipy.stats as stats
import numpy as np
import pandas as pd
df_president = pd.read_csv('1976-2016-president.csv')
df_vaccine = pd.read_csv('NISPUF17.csv')

#voting data
df_president = (df_president[['state_fips','candidate','candidatevotes','party','writein']]
                .dropna()
                .loc[df_president['year'] == 2016]) #get useful columns and year 2016
trump_votes = (df_president
               .loc[(df_president['candidate'] == 'Trump, Donald J.')& ~(df_president["writein"])]
               .loc[df_president['party'] == 'republican']) #Get trump, clean up party column and writein column
clinton_votes = (df_president
                 .loc[(df_president['candidate'] == 'Clinton, Hillary')& ~(df_president["writein"])]
                 .loc[df_president['party'] == 'democrat']) #likewise
trump_clinton_votes = pd.merge(trump_votes, clinton_votes, on = "state_fips") #merge
trump_clinton_votes['ratio'] = (trump_clinton_votes['candidatevotes_x'])/trump_clinton_votes['candidatevotes_y'] #ratio

#vaccine data
df_vaccine = df_vaccine[["STATE","P_NUMVRC"]]#get two useful columns
df_no_vaccine = (df_vaccine [df_vaccine['P_NUMVRC'] == 0]
                 .groupby(["STATE"])
                 .size()
                 .to_frame("count")
                 .reset_index()
                 .rename(columns= {"STATE":"state", "count":"no_vaccine"})) #get no vaccine data
df_yes_vaccine = (df_vaccine [df_vaccine['P_NUMVRC'] >= 1]
                  .groupby(["STATE"])
                  .size()
                  .to_frame("count")
                  .reset_index()
                  .rename(columns= {"STATE":"state", "count":"yes_vaccine"})) #get yes vaccine data
merge_vaccine = pd.merge(df_no_vaccine,df_yes_vaccine , on = "state") #merge
ratio_vaccine = merge_vaccine['yes_vaccine']/(( merge_vaccine['no_vaccine']))
corr, pval=stats.pearsonr(trump_clinton_votes['ratio'],ratio_vaccine)
corr
# Out:
# -0.2790809695271168

# %%
#closer to real answer version

# %matplotlib inline
import scipy.stats as stats
import numpy as np
import pandas as pd
df_president = pd.read_csv('1976-2016-president.csv')
df_vaccine = pd.read_csv('NISPUF17.csv')

#voting data
df_president = (df_president[['state_fips','candidate','candidatevotes','writein']]
                .dropna()
                .loc[df_president['year'] == 2016]) #get useful columns and year 2016
trump_votes = (df_president
               .loc[(df_president['candidate'] == 'Trump, Donald J.')& ~(df_president["writein"])]
               .loc[df_president['party'] == 'republican']) #Get trump, clean up party column and writein column
clinton_votes = (df_president
                 .loc[(df_president['candidate'] == 'Clinton, Hillary')& ~(df_president["writein"])]
                 .loc[df_president['party'] == 'democrat']) #likewise
trump_clinton_votes = pd.merge(trump_votes, clinton_votes, on = "state_fips") #merge
trump_clinton_votes['ratio'] = (trump_clinton_votes['candidatevotes_x'])/trump_clinton_votes['candidatevotes_y'] #ratio

#vaccine data
df_vaccine = df_vaccine[["STATE","P_NUMVRC"]]#get two useful columns
df_no_vaccine = (df_vaccine [df_vaccine['P_NUMVRC'] == 0]
                 .groupby(["STATE"])
                 .size()
                 .to_frame("count")
                 .reset_index()
                 .rename(columns= {"STATE":"state", "count":"no_vaccine"})) #get no vaccine data
df_yes_vaccine = (df_vaccine [df_vaccine['P_NUMVRC'] >= 1]
                  .groupby(["STATE"])
                  .size()
                  .to_frame("count")
                  .reset_index()
                  .rename(columns= {"STATE":"state", "count":"yes_vaccine"})) #get yes vaccine data
merge_vaccine = pd.merge(df_no_vaccine,df_yes_vaccine , on = "state") #merge
ratio_vaccine = merge_vaccine['yes_vaccine']/(( merge_vaccine['no_vaccine']))
corr, pval=stats.pearsonr(trump_clinton_votes['ratio'],ratio_vaccine)
print(corr,pval)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'party'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-7c914a746459> in <module>()
#      14 trump_votes = (df_president
# ...

# %%
df_president
# Out:
#       state_fips                      candidate  candidatevotes  writein
# 3395           1               Trump, Donald J.         1318255    False
# 3396           1               Clinton, Hillary          729547    False
# 3397           1                  Johnson, Gary           44467    False
# 3399           1                    Stein, Jill            9391    False
# 3400           2               Trump, Donald J.          163387    False
# 3401           2               Clinton, Hillary          116454    False
# 3402           2                  Johnson, Gary           18725    False
# 3404           2                    Stein, Jill            5735    False
# 3405           2             Castle, Darrell L.            3866    False
# 3406           2  De La Fuente, Roque ""Rocky""            1240    False
# 3407           4               Trump, Donald J.         1252401    False
# 3408           4               Clinton, Hillary         1161167    False
# ...

# %%
df_president_votes = df_president[['state','state_po','candidate','candidatevotes']]
#df_president_votes = df_president_votes.loc[(df_president["candidate"] == "Trump, Donald J.")|(df_president["candidate"] == "Clinton, Hillary")]
df_trump_votes = df_president_votes.loc[(df_president["candidate"] == "Trump, Donald J.")]#.head().sort_index(inplace=True)

df_hillary_votes = df_president_votes.loc[(df_president["candidate"] == "Clinton, Hillary")]#.head().sort_index(inplace=True)


#df_president_votes['candidatevotes']

# %%
# %matplotlib inline
def corr_election():
    import scipy.stats as stats
    import numpy as np
    import pandas as pd
    
    df_president = pd.read_csv('1976-2016-president.csv')
    df_fed=pd.read_html("https://en.wikipedia.org/wiki/Federal_Information_Processing_Standard_state_code#FIPS_state_codes")[0]
    df_vaccine = pd.read_csv('NISPUF17.csv')
    #df_vaccine = df_vaccine.loc[(df_vaccine["HAD_CPOX"] == 1)|(df_vaccine["HAD_CPOX"] == 2)]
    df_president = df_president.loc[(df_president["year"] == 2016)] #get only year 2016
    del df_president['notes']
    
    #election data
    df_president.loc[(df_president["candidate"] == "Trump, Donald J.")|(df_president["candidate"] == "Clinton, Hillary")].head() #get only trump and hillary
    df_president_votes = df_president[['state','state_po','candidate','candidatevotes']]
    #df_president_votes = df_president_votes.loc[(df_president["candidate"] == "Trump, Donald J.")|(df_president["candidate"] == "Clinton, Hillary")]
    df_trump_votes = df_president_votes.loc[(df_president["candidate"] == "Trump, Donald J.")]#.head().sort_index(inplace=True)

    df_hillary_votes = df_president_votes.loc[(df_president["candidate"] == "Clinton, Hillary")]#.head().sort_index(inplace=True)


    #df_president_votes['candidatevotes']
    df_trump_votes = df_trump_votes[['state','candidatevotes']].reset_index() #create new df trump votes
    df_hillary_votes= df_hillary_votes[['state','candidatevotes']].reset_index() #create new df hillary votes
    df_trump_vs_hillary = pd.merge(df_trump_votes, df_hillary_votes, how='outer', left_index=True, right_index=True) #merge
    df_trump_vs_hillary = df_trump_vs_hillary.rename(columns= {"state_x":"state", "candidatevotes_x":"trump","candidatevotes_y":"hillary"}) #change axis title
    df_trump_vs_hillary = df_trump_vs_hillary[['state','trump','hillary']] #get useful columns
    trump_win_mask = df_trump_vs_hillary['trump'] > df_trump_vs_hillary['hillary']  #create if trump wins mask
    hillary_win_mask = df_trump_vs_hillary['trump'] < df_trump_vs_hillary['hillary'] #create if hillary wins mask
    hillary_states = df_trump_vs_hillary[['state','hillary']].where(hillary_win_mask).dropna()#.reset_index().drop(['index'], axis=1) #apply mask for hillary, drop no number rows, remove index column
    trump_states = df_trump_vs_hillary.where(trump_win_mask).dropna() #apply mask for trump, drop no number rows, remove index column
    trump_hillary_wins = pd.merge(hillary_states[['state']], trump_states[['state']], how='right', left_index=True, right_index=True) #merge candidate win state respectively
    trump_hillary_wins.rename(columns= {"state_x":"hillary_state", "state_y":"trump_state"}) #rename columns
    trump_hillary_wins['ratio'] = df_trump_vs_hillary['trump']/df_trump_vs_hillary['hillary']
    trump_hillary_wins['ratio']
    
    #vaccine data
    
    df_vaccine = pd.read_csv('NISPUF17.csv')
    df_vaccine = df_vaccine[["STATE","P_NUMVRC"]].dropna()
    df_no_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] == 0].reset_index()
    df_yes_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] >= 1].reset_index()
    count_no_vaccine = df_no_vaccine.groupby(["STATE"]).size().to_frame("count").reset_index()
    count_yes_vaccine = df_yes_vaccine.groupby(["STATE"]).size().to_frame("count").reset_index()
    count_yes_vaccine = count_yes_vaccine.rename(columns= {"STATE":"state", "count":"yes_vaccine"}) #change axis title
    count_no_vaccine = count_no_vaccine.rename(columns= {"STATE":"state", "count":"no_vaccine"}) #change axis title
    merge_vaccine = pd.merge(count_no_vaccine, count_yes_vaccine, how='right', left_index=True, right_index=True)
    merge_vaccine = merge_vaccine[["state_x","no_vaccine","yes_vaccine"]]
    merge_vaccine = merge_vaccine.rename(columns= {"state_x":"state"})
    total_vaccine = (( merge_vaccine['no_vaccine'])+(merge_vaccine['yes_vaccine']))
    ratio_vaccine['ratio'] = merge_vaccine['yes_vaccine']/total_vaccine
    df.plot()    
    # here is some stub code to actually run the correlation
    corr, pval=stats.pearsonr(trump_hillary_wins['ratio'],ratio_vaccine['ratio'])
    print(corr,pval)
    # just return the correlation at the end
    return corr, pval

# %%
trump_clinton_votes['ratio'].plot()

# %%
#working copy
# %matplotlib inline

import scipy.stats as stats
import numpy as np
import pandas as pd

df_president = pd.read_csv('1976-2016-president.csv')
df_fed=pd.read_html("https://en.wikipedia.org/wiki/Federal_Information_Processing_Standard_state_code#FIPS_state_codes")[0]
df_vaccine = pd.read_csv('NISPUF17.csv')
df_vaccine = df_vaccine.loc[(df_vaccine["HAD_CPOX"] == 1)|(df_vaccine["HAD_CPOX"] == 2)]
df_president = df_president.loc[(df_president["year"] == 2016)] #get only year 2016
del df_president['notes']

df_president = pd.read_csv('1976-2016-president.csv')
df_fed=pd.read_html("https://en.wikipedia.org/wiki/Federal_Information_Processing_Standard_state_code#FIPS_state_codes")[0]

df_president = df_president.loc[df_president['year'] == 2016]
df_president = df_president[['state_fips','candidate','candidatevotes','party','writein']].dropna()
trump_votes = df_president.loc[(df_president['candidate'] == 'Trump, Donald J.')& ~(df_president["writein"])].loc[df_president['party'] == 'republican']#.loc[df_president['writein'] == 'False']
clinton_votes = df_president.loc[(df_president['candidate'] == 'Clinton, Hillary')& ~(df_president["writein"])].loc[df_president['party'] == 'democrat']
trump_clinton_votes = pd.merge(trump_votes, clinton_votes, on = "state_fips")
trump_clinton_votes['ratio'] = (trump_clinton_votes['candidatevotes_x'])/trump_clinton_votes['candidatevotes_y']
#trump_clinton_votes.loc[trump_clinton_votes['writein_x'] is not True],
#type( trump_clinton_votes['writein_x'][23])
trump_clinton_votes['ratio']


#vaccine data

df_vaccine = pd.read_csv('NISPUF17.csv')
#df_vaccine = df_vaccine.loc[(df_vaccine["HAD_CPOX"] == 1)|(df_vaccine["HAD_CPOX"] == 2)]
df_vaccine = df_vaccine[["STATE","P_NUMVRC"]]#.dropna()
df_no_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] == 0].reset_index()
df_yes_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] >= 1].reset_index()
count_no_vaccine = df_no_vaccine.groupby(["STATE"]).size().to_frame("count").reset_index()
count_yes_vaccine = df_yes_vaccine.groupby(["STATE"]).size().to_frame("count").reset_index()
#.size().groupby("STATE").to_frame('count')
#df_no_vaccine
count_yes_vaccine = count_yes_vaccine.rename(columns= {"STATE":"state", "count":"yes_vaccine"}) #change axis title
count_no_vaccine = count_no_vaccine.rename(columns= {"STATE":"state", "count":"no_vaccine"}) #change axis title
merge_vaccine = pd.merge(count_no_vaccine,count_yes_vaccine , on = "state")
merge_vaccine
#merge_vaccine = merge_vaccine[["state_x","no_vaccine","yes_vaccine"]]
total_vaccine = (( merge_vaccine['no_vaccine'])+(merge_vaccine['yes_vaccine']))
ratio_vaccine = merge_vaccine['yes_vaccine']/total_vaccine
#len(ratio_vaccine)

#df.plot()    
# here is some stub code to actually run the correlation
corr, pval=stats.pearsonr(trump_clinton_votes['ratio'],ratio_vaccine)
#len(trump_clinton_votes[['ratio']])
# just return the correlation at the end
print(corr,pval)
# Out:
# -0.2601154923758659 0.0652680729771062

# %%
df_president = pd.read_csv('1976-2016-president.csv')
df_fed=pd.read_html("https://en.wikipedia.org/wiki/Federal_Information_Processing_Standard_state_code#FIPS_state_codes")[0]
df_president.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# 1             Ford, Gerald                  republican    False
# 2           Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin ""Ben""                 prohibition    False
# 4                Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes
# 0          659170     1182850  20171015    NaN
# ...

# %%
df_president = pd.read_csv('1976-2016-president.csv')
df_fed=pd.read_html("https://en.wikipedia.org/wiki/Federal_Information_Processing_Standard_state_code#FIPS_state_codes")[0]

df_president = df_president.loc[df_president['year'] == 2016]
df_president = df_president[['state_fips','candidate','candidatevotes','party','writein']].dropna()
trump_votes = df_president.loc[(df_president['candidate'] == 'Trump, Donald J.')& ~(df_president["writein"])].loc[df_president['party'] == 'republican']#.loc[df_president['writein'] == 'False']
clinton_votes = df_president.loc[(df_president['candidate'] == 'Clinton, Hillary')& ~(df_president["writein"])].loc[df_president['party'] == 'democrat']
trump_clinton_votes = pd.merge(trump_votes, clinton_votes, on = "state_fips")
trump_clinton_votes['ratio'] = (trump_clinton_votes['candidatevotes_x'])/trump_clinton_votes['candidatevotes_y']
#trump_clinton_votes.loc[trump_clinton_votes['writein_x'] is not True],
#type( trump_clinton_votes['writein_x'][23])
trump_clinton_votes['ratio']
# Out:
#     state_fips       candidate_x  candidatevotes_x     party_x  writein_x  \
# 0            1  Trump, Donald J.           1318255  republican      False
# 1            2  Trump, Donald J.            163387  republican      False
# 2            4  Trump, Donald J.           1252401  republican      False
# 3            5  Trump, Donald J.            684872  republican      False
# 4            6  Trump, Donald J.           4483810  republican      False
# 5            8  Trump, Donald J.           1202484  republican      False
# 6            9  Trump, Donald J.            673215  republican      False
# 7           10  Trump, Donald J.            185127  republican      False
# 8           11  Trump, Donald J.             12723  republican      False
# 9           12  Trump, Donald J.           4617886  republican      False
# 10          13  Trump, Donald J.           2089104  republican      False
# 11          15  Trump, Donald J.            128847  republican      False
# ...

# %%
len(ratio_vaccine)
# Out:
# 52

# %%
#df_president_votes['candidatevotes']



df_trump_votes = df_trump_votes[['state','candidatevotes']].reset_index() #create new df trump votes
df_hillary_votes= df_hillary_votes[['state','candidatevotes']].reset_index() #create new df hillary votes
df_trump_vs_hillary = pd.merge(df_trump_votes, df_hillary_votes, how='outer', left_index=True, right_index=True) #merge
df_trump_vs_hillary = df_trump_vs_hillary.rename(columns= {"state_x":"state", "candidatevotes_x":"trump","candidatevotes_y":"hillary"}) #change axis title
df_trump_vs_hillary = df_trump_vs_hillary[['state','trump','hillary']] #get useful columns
trump_win_mask = df_trump_vs_hillary['trump'] > df_trump_vs_hillary['hillary']  #create if trump wins mask
hillary_win_mask = df_trump_vs_hillary['trump'] < df_trump_vs_hillary['hillary'] #create if hillary wins mask
hillary_states = df_trump_vs_hillary[['state','hillary']].where(hillary_win_mask).dropna()#.reset_index().drop(['index'], axis=1) #apply mask for hillary, drop no number rows, remove index column
trump_states = df_trump_vs_hillary.where(trump_win_mask).dropna() #apply mask for trump, drop no number rows, remove index column
trump_hillary_wins = pd.merge(hillary_states[['state']], trump_states[['state']], how='right', left_index=True, right_index=True) #merge candidate win state respectively
trump_hillary_wins.rename(columns= {"state_x":"hillary_state", "state_y":"trump_state"}) #rename columns
trump_hillary_wins['ratio'] = df_trump_vs_hillary['trump']/df_trump_vs_hillary['hillary']
df_trump_vs_hillary['ratio'] = df_trump_vs_hillary['trump']/df_trump_vs_hillary['hillary'] #get ratio
df_trump_vs_hillary.dropna()

df_trump_vs_hillary = pd.merge(df_fed, df_trump_vs_hillary, how='right', left_index=True, right_index=True)
df_trump_vs_hillary
# Out:
#                                  0           1             2  \
# 0                             Name  Alpha code  Numeric code
# 1                          Alabama          AL            01
# 2                           Alaska          AK            02
# 3                   American Samoa          AS            60
# 4                 American Samoa *         NaN            03
# 5                          Arizona          AZ            04
# 6                         Arkansas          AR            05
# 7                     Baker Island         NaN            81
# 8                       California          CA            06
# 9                     Canal Zone *         NaN            07
# 10                        Colorado          CO            08
# 11                     Connecticut          CT            09
# 12                        Delaware          DE            10
# 13            District of Columbia          DC            11
# ...

# %%
corr_election()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-283-b06b3feb7873> in <module>()
# ----> 1 corr_election()
#
# <ipython-input-282-c4a2e2448a75> in corr_election()
#      53     df.plot()
#      54     # here is some stub code to actually run the correlation
# ---> 55     corr, pval=stats.pearsonr(trump_hillary_wins['ratio'],ratio_vaccine['ratio'])
#      56     print(corr,pval)
#      57     # just return the correlation at the end
#
# ~/miniconda3/lib/python3.6/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3387     n = len(x)
#    3388     if n != len(y):
# -> 3389         raise ValueError('x and y must have the same length.')
#    3390
#    3391     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
# is there a relationship between states which voted for the republican candidate for president in 2016 (Trump) 
#versus those who voted for the democratic candidate for president in 2016 (Hillary) and the rate of vaccination in those states in 2017? 
#I would like you to answer this by doing a correlation test between the ratio of votes for Trump/Clinton against the ratio of Vaccination/Non-Vaccination (of Chickenpox!) by state.

# Note: You are certainly using joins or merges here.

# Note: You will might need the state FIPS identifiers and will certainly want the MIT Elections Data which has the results from 2018.

# Note: I don't know the answer to this question already.



df_president.loc[(df_president["candidate"] == "Trump, Donald J.")|(df_president["candidate"] == "Clinton, Hillary")].head() #get only trump and hillary
df_trump_votes = df_trump_votes[['state','candidatevotes']].reset_index() #create new df trump votes
df_hillary_votes= df_hillary_votes[['state','candidatevotes']].reset_index() #create new df hillary votes
df_trump_vs_hillary = pd.merge(df_trump_votes, df_hillary_votes, how='outer', left_index=True, right_index=True) #merge
df_trump_vs_hillary = df_trump_vs_hillary.rename(columns= {"state_x":"state", "candidatevotes_x":"trump","candidatevotes_y":"hillary"}) #change axis title
df_trump_vs_hillary = df_trump_vs_hillary[['state','trump','hillary']] #get useful columns
trump_win_mask = df_trump_vs_hillary['trump'] > df_trump_vs_hillary['hillary']  #create if trump wins mask
hillary_win_mask = df_trump_vs_hillary['trump'] < df_trump_vs_hillary['hillary'] #create if hillary wins mask
hillary_states = df_trump_vs_hillary[['state','hillary']].where(hillary_win_mask).dropna()#.reset_index().drop(['index'], axis=1) #apply mask for hillary, drop no number rows, remove index column
trump_states = df_trump_vs_hillary.where(trump_win_mask).dropna() #apply mask for trump, drop no number rows, remove index column
trump_hillary_wins = pd.merge(hillary_states[['state']], trump_states[['state']], how='right', left_index=True, right_index=True) #merge candidate win state respectively
#trump_hillary_wins.rename(columns= {"state_x":"hillary_state", "state_y":"trump_state"}) #rename columns
df_trump_vs_hillary['ratio'] = df_trump_vs_hillary['trump']/df_trump_vs_hillary['hillary']
df_trump_vs_hillary
# Out:
#                    state      trump  hillary      ratio
# 0                Alabama  1318255.0   729547   1.806950
# 1                 Alaska   163387.0   116454   1.403018
# 2                Arizona  1252401.0  1161167   1.078571
# 3               Arkansas   684872.0   380494   1.799955
# 4             California  4483810.0  8753788   0.512214
# 5               Colorado  1202484.0  1338870   0.898134
# 6            Connecticut   673215.0   897572   0.750040
# 7               Delaware   185127.0   235603   0.785758
# 8   District of Columbia    12723.0   282830   0.044985
# 9                Florida  4617886.0  4504975   1.025064
# 10               Georgia  2089104.0  1877963   1.112431
# 11                Hawaii   128847.0   266891   0.482770
# 12                 Idaho   409055.0   189765   2.155587
# 13              Illinois  2146015.0  3090729   0.694339
# 14               Indiana  1557286.0  1033126   1.507353
# 15                  Iowa   800983.0   653669   1.225365
# ...

# %%
df_fed
# Out:
#                                  0           1             2  \
# 0                             Name  Alpha code  Numeric code
# 1                          Alabama          AL            01
# 2                           Alaska          AK            02
# 3                   American Samoa          AS            60
# 4                 American Samoa *         NaN            03
# 5                          Arizona          AZ            04
# 6                         Arkansas          AR            05
# 7                     Baker Island         NaN            81
# 8                       California          CA            06
# 9                     Canal Zone *         NaN            07
# 10                        Colorado          CO            08
# 11                     Connecticut          CT            09
# 12                        Delaware          DE            10
# 13            District of Columbia          DC            11
# ...

# %%
df_president.loc[(df_president["candidate"] == "Trump, Donald J.")|(df_president["candidate"] == "Clinton, Hillary")].head()
df_president.head()
df_trump_votes = df_trump_votes[['state','candidatevotes']].reset_index()
df_trump_votes
df_president = pd.merge(df_president,df_fed, how='outer', left_index=True, right_index=True)
df_president
# Out:
#     0_x  1_x  2_x  3_x  year state state_po  state_fips  state_cen  state_ic  \
# 0   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 1   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 2   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 3   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 4   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 5   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 6   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 7   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 8   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 9   NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# 10  NaN  NaN  NaN  NaN   NaN   NaN      NaN         NaN        NaN       NaN
# ...

# %%
df_vaccine = df_vaccine.dropna().reset_index()
df_no_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] == 0].reset_index()
count_no_vaccine = df_no_vaccine.groupby(["STATE"]).size().to_frame("count").reset_index()
count_no_vaccine
# Out:
#     STATE  count
# 0       1     22
# 1       2     39
# 2       4     23
# 3       5     24
# 4       6     22
# 5       8     32
# 6       9     13
# 7      10     16
# 8      11     12
# 9      12     32
# 10     13     22
# 11     15     26
# 12     16     20
# 13     17     34
# 14     18     36
# 15     19     18
# 16     20     24
# 17     21     15
# 18     22     26
# 19     23     30
# 20     24     21
# 21     25     10
# 22     26     15
# 23     27     19
# 24     28     20
# 25     29     30
# 26     30     19
# 27     31     13
# 28     32     18
# 29     33     18
# 30     34     33
# 31     35     22
# 32     36     52
# 33     37     25
# 34     38     14
# 35     39     36
# 36     40     24
# 37     41     26
# 38     42     46
# 39     44     15
# 40     45     24
# 41     46     24
# 42     47     13
# 43     48    124
# 44     49     35
# 45     50     29
# 46     51     15
# 47     53     27
# 48     54     28
# 49     55     25
# 50     56     32

# %%
#find vaccine by state in 2017

df_vaccine = pd.read_csv('NISPUF17.csv')
#df_vaccine = df_vaccine.loc[(df_vaccine["HAD_CPOX"] == 1)|(df_vaccine["HAD_CPOX"] == 2)]
df_vaccine = df_vaccine[["STATE","P_NUMVRC"]]#.dropna()
df_no_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] == 0].reset_index()
df_yes_vaccine = df_vaccine [df_vaccine['P_NUMVRC'] >= 1].reset_index()
count_no_vaccine = df_no_vaccine.groupby(["STATE"]).size().to_frame("count").reset_index()
count_yes_vaccine = df_yes_vaccine.groupby(["STATE"]).size().to_frame("count").reset_index()
#.size().groupby("STATE").to_frame('count')
#df_no_vaccine
count_yes_vaccine = count_yes_vaccine.rename(columns= {"STATE":"state", "count":"yes_vaccine"}) #change axis title
count_no_vaccine = count_no_vaccine.rename(columns= {"STATE":"state", "count":"no_vaccine"}) #change axis title
merge_vaccine = pd.merge(count_no_vaccine,count_yes_vaccine , on = "state")
merge_vaccine
#merge_vaccine = merge_vaccine[["state_x","no_vaccine","yes_vaccine"]]
total_vaccine = (( merge_vaccine['no_vaccine'])+(merge_vaccine['yes_vaccine']))
ratio_vaccine = merge_vaccine['yes_vaccine']/total_vaccine
len(ratio_vaccine)

#df_vaccine.dropna().reset_index()
# Out:
# 51

# %%
vaccine_by_state = pd.merge(df_fed, df_vaccine, how='outer', left_index=True, right_index=True)
vaccine_by_state
# Out:
#                                     0           1             2  \
# 0                                Name  Alpha code  Numeric code
# 1                             Alabama          AL            01
# 2                              Alaska          AK            02
# 3                      American Samoa          AS            60
# 4                    American Samoa *         NaN            03
# 5                             Arizona          AZ            04
# 6                            Arkansas          AR            05
# 7                        Baker Island         NaN            81
# 8                          California          CA            06
# 9                        Canal Zone *         NaN            07
# 10                           Colorado          CO            08
# 11                        Connecticut          CT            09
# 12                           Delaware          DE            10
# 13               District of Columbia          DC            11
# ...

# %%
trump_hillary_wins = pd.merge(hillary_states, trump_states, how='right', left_index=True, right_index=True) #merge candidate win state respectively
trump_hillary_wins.rename(columns= {"state_x":"hillary_state", "state_y":"trump_state"}) #rename columns
# Out:
#            hillary_state    hillary     trump_state      trump
# 0             California  8753788.0         Alabama  1318255.0
# 1               Colorado  1338870.0          Alaska   163387.0
# 2            Connecticut   897572.0         Arizona  1252401.0
# 3               Delaware   235603.0        Arkansas   684872.0
# 4   District of Columbia   282830.0         Florida  4617886.0
# 5                 Hawaii   266891.0         Georgia  2089104.0
# 6               Illinois  3090729.0           Idaho   409055.0
# 7                  Maine   357735.0         Indiana  1557286.0
# 8               Maryland  1677928.0            Iowa   800983.0
# 9          Massachusetts  1995196.0          Kansas   671018.0
# 10             Minnesota  1367705.0        Kentucky  1202971.0
# 11                Nevada   539260.0       Louisiana  1178638.0
# 12         New Hampshire   348526.0        Maryland      259.0
# 13            New Jersey  2148278.0        Michigan  2279543.0
# ...

# %%
hillary_states = df_trump_vs_hillary[['state','hillary']].where(hillary_win_mask).dropna().reset_index().drop(['index'], axis=1)
hillary_states
# Out:
#                    state    hillary
# 0             California  8753788.0
# 1               Colorado  1338870.0
# 2            Connecticut   897572.0
# 3               Delaware   235603.0
# 4   District of Columbia   282830.0
# 5                 Hawaii   266891.0
# 6               Illinois  3090729.0
# 7                  Maine   357735.0
# 8               Maryland  1677928.0
# 9          Massachusetts  1995196.0
# 10             Minnesota  1367705.0
# 11                Nevada   539260.0
# 12         New Hampshire   348526.0
# 13            New Jersey  2148278.0
# 14            New Mexico   385234.0
# 15              New York  4379789.0
# 16          North Dakota  2189316.0
# 17              Oklahoma  2394164.0
# 18          Rhode Island  2926441.0
# 19          South Dakota   855373.0
# 20                  Utah  3877868.0
# 21               Vermont   310674.0
# 22            Washington  1981473.0
# 23         West Virginia  1742718.0
# 24               Wyoming  1382536.0

# %%
trump_states = df_trump_vs_hillary.where(trump_win_mask).dropna().reset_index().drop(['index','hillary'], axis=1)
trump_states
# Out:
#              state      trump
# 0          Alabama  1318255.0
# 1           Alaska   163387.0
# 2          Arizona  1252401.0
# 3         Arkansas   684872.0
# 4          Florida  4617886.0
# 5          Georgia  2089104.0
# 6            Idaho   409055.0
# 7          Indiana  1557286.0
# 8             Iowa   800983.0
# 9           Kansas   671018.0
# 10        Kentucky  1202971.0
# 11       Louisiana  1178638.0
# 12        Maryland      259.0
# 13        Michigan  2279543.0
# 14     Mississippi   700714.0
# 15        Missouri  1594511.0
# 16         Montana   279240.0
# 17        Nebraska   495961.0
# 18        New York   292392.0
# 19  North Carolina  2362631.0
# 20            Ohio  2841005.0
# 21          Oregon   782403.0
# 22    Pennsylvania  2970733.0
# 23  South Carolina  1155389.0
# 24       Tennessee  1522925.0
# 25           Texas  4685047.0
# 26        Virginia  1769443.0
# 27       Wisconsin  1405284.0

# %%
(df_trump_votes[['candidatevotes']]) > (df_hillary_votes[['candidatevotes']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-168-5018b4bcfb96> in <module>()
# ----> 1 (df_trump_votes[['candidatevotes']]) > (df_hillary_votes[['candidatevotes']])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
df_president_votes['Win'] = np.where(df_trump_votes.candidatevotes > df_hillary_votes.candidatevotes, 'True', 'False')
df_president_votes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-169-7d66a30dade5> in <module>()
# ----> 1 df_president_votes['Win'] = np.where(df_trump_votes.candidatevotes > df_hillary_votes.candidatevotes, 'True', 'False')
#       2 df_president_votes
#
# AttributeError: 'NoneType' object has no attribute 'candidatevotes'

# %%
#df_president.head().drop("notes")
df

df_president = df_president.loc[(df_president["candidate"] == "Trump, Donald J.")|(df_president["candidate"] == "Clinton, Hillary")]

#df_president[["state_po",'candidate']].head()#.to_frame("count")
#pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)

# %%
df_fed
# Out:
#                                  0           1             2  \
# 0                             Name  Alpha code  Numeric code
# 1                          Alabama          AL            01
# 2                           Alaska          AK            02
# 3                   American Samoa          AS            60
# 4                 American Samoa *         NaN            03
# 5                          Arizona          AZ            04
# 6                         Arkansas          AR            05
# 7                     Baker Island         NaN            81
# 8                       California          CA            06
# 9                     Canal Zone *         NaN            07
# 10                        Colorado          CO            08
# 11                     Connecticut          CT            09
# 12                        Delaware          DE            10
# 13            District of Columbia          DC            11
# ...

# %%
l1 = [1,2,3]

help( list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...

# %%
df["P_NUMVRC"].dropna()
# Out:
# 3        1.0
# 4        0.0
# 6        1.0
# 7        0.0
# 8        0.0
# 10       1.0
# 12       1.0
# 16       2.0
# 19       1.0
# 20       1.0
# 21       1.0
# 22       1.0
# 24       1.0
# 25       1.0
# 26       1.0
# 27       1.0
# 28       1.0
# 29       1.0
# 30       1.0
# 34       1.0
# 35       1.0
# 36       0.0
# 39       1.0
# 40       1.0
# 41       1.0
# 43       1.0
# 44       1.0
# 46       1.0
# 47       1.0
# 49       1.0
#         ...
# 28397    1.0
# 28398    0.0
# 28400    1.0
# 28402    1.0
# 28403    1.0
# 28404    1.0
# 28406    1.0
# 28407    1.0
# 28408    0.0
# 28409    1.0
# 28410    1.0
# 28411    1.0
# 28412    1.0
# 28415    1.0
# 28418    1.0
# 28422    1.0
# 28424    1.0
# 28425    1.0
# 28427    1.0
# 28430    1.0
# 28435    1.0
# 28436    1.0
# 28437    1.0
# 28438    1.0
# 28440    1.0
# 28446    1.0
# 28447    1.0
# 28449    1.0
# 28452    1.0
# 28454    1.0
# Name: P_NUMVRC, Length: 15333, dtype: float64
